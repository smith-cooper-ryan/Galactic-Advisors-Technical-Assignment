# %% [markdown]
# ## User Story:
# The IT department of _**Plain Corp**_ has implemented a custom-built _Computer Management Solution (CMS)_ which comes with a feature that reports information about computers in their environment such as metadata, installed programs and logins. The current problem faced by the IT team is that the reports created by CMS do not answer all the questions they have about the computers in their environment. Luckily, they figured out that the CMS stores its raw data in a SQLite (v3.45.0)  _database (DB)_ file and that they could write custom SQL queries to report the information not provided within the CMS reports.
#
# ## Goal:
# Your job will be to update this Jupyter Notebook with the SQL queries needed to meet the IT team’s reporting needs. It is recommended to use a Database IDE to help with query writing and data exploration.
#
# ## Directions:
# Download the attached zip file which contains all the files you need to complete this assignment. Below is a description of each of the three files within the attached zip file:
# - **cms.sqlite**: The database you must query from to complete this assignment.
# - **cms_data_dictionary.txt**: A data dictionary describing the tables within this database.
# - **GA Mission - Data Analyst.ipynb**: The Jupyter Notebook file you must update to complete the assignment. Rules to abide by while completing this assignment are listed within this Jupyter Notebook.
#
# ## Our Expectations
# This assignment <ins>**should take you no longer than 2 hours**</ins> to complete. Make sure your outputs are visible in a web browser when uploaded to a public repository and that they are presented in a way that is understandable by someone with some technical experience but no programming experience. Extra rules to abide by are described in the included Juptyter Notebook file.
#
# We would prefer that you share the code with us by pushing it to a public repository in the hosting provider of your choosing. If you do not want to upload it to a public repository then you can zip up the repository folder on your machine and send it to us via email. If you go that route, please make sure that the .git folder is included.
#
# We recommend  that you use a Database IDE (e.g., DBeaver, Datagrip, etc.) to assist with query writing and data exploration. If you have any questions, please contact us and we will do our best to clarify anything that is unclear.
#
# ## Rules:
# - The code should be stored in a git repository.
# - With the exception of ***Pandas***, you can use any Python Packages you like.
# - Do not edit the data in the **cms.sqlite** DB file.
# - Your query results must be output in a _Pandas DataFrame (PD)_.
# - Questions 4 and 5 are written answer questions where no code or SQL is necessary.
# - Question 6 is a written answer question that may require code or SQL depending on your answer. This question can be thought of as a chance to share any observations you've made or perform a light EDA on the data. There are no right or wrong answers for this question.

# %% [markdown]
# # Questions

# %%
# !pip install ipython-sql
# %load_ext sql
import pandas            as pd
import numpy             as np
import regex             as re
import matplotlib        as mpl
import matplotlib.pyplot as plt
from sqlite3 import connect
import sqlalchemy
# %sql sqlite:///cms.sqlite
conn = connect("cms.sqlite")
# Out:
# Requirement already satisfied: ipython-sql in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (0.5.0)
# Requirement already satisfied: prettytable in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython-sql) (3.9.0)
# Requirement already satisfied: ipython in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython-sql) (8.15.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython-sql) (2.0.25)
# Requirement already satisfied: sqlparse in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython-sql) (0.4.4)
# Requirement already satisfied: six in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython-sql) (1.16.0)
# Requirement already satisfied: ipython-genutils in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from sqlalchemy>=2.0->ipython-sql) (4.9.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from sqlalchemy>=2.0->ipython-sql) (3.0.3)
# Requirement already satisfied: backcall in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: decorator in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (0.18.1)
# Requirement already satisfied: matplotlib-inline in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (0.1.6)
# Requirement already satisfied: pickleshare in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (3.0.43)
# Requirement already satisfied: pygments>=2.4.0 in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (2.15.1)
# Requirement already satisfied: stack-data in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: traitlets>=5 in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from ipython->ipython-sql) (4.8.0)
# Requirement already satisfied: wcwidth in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from prettytable->ipython-sql) (0.2.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)
# Requirement already satisfied: executing in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (0.8.3)
# Requirement already satisfied: asttokens in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (2.0.5)
# Requirement already satisfied: pure-eval in /home/rycaga/Applications/home/rycaga/Applications/anaconda3/lib/python3.11/site-packages (from stack-data->ipython->ipython-sql) (0.2.2)
# DEPRECATION: textract 1.6.5 has a non-standard dependency specifier extract-msg<=0.29.*. pip 23.3 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of textract or contact the author to suggest that they release a version with a conforming dependency specifiers. Discussion can be found at https://github.com/pypa/pip/issues/12063
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %% [markdown]
# ###### Foreword

# %% [markdown]
# The rules were somewhat unclear, as Pandas was excluded from use in the solutions but query results were specified to be in a Pandas DataFrame. Question 3b specifically mentions Pandas as well, and as such the SQL queries are shown in both Pandas and non-Pandas variants for each question. For questions 1-3, little narrative is neccesary as each question gives a specified end-result and the output SQL tables and Pandas DataFrames are intuitively named for easy reading.

# %% [markdown]
#  <font size='5'> 1. Count how many Admin and Regular computers are in the database.</font>

# %%
# %%sql
#
# SELECT computer_type, count(computer_type)
# FROM computers
# WHERE computer_type LIKE 'Admin'
# OR    computer_type LIKE 'Regular'
# GROUP BY computer_type;
# Out:
#  * sqlite:///cms.sqlite
# Done.
# [('Admin', 8), ('Regular', 24)]

# %%
query = '''
SELECT computer_type, count(computer_type)
FROM computers
WHERE computer_type LIKE 'Admin'
OR    computer_type LIKE 'Regular'
GROUP BY computer_type;
'''

df = pd.read_sql(query, conn)
df.head()
# Out:
#   computer_type  count(computer_type)
# 0         Admin                     8
# 1       Regular                    24

# %% [markdown]
# <font size='5'>2a. Identify all non-admin computers with the programs **Bitwarden**, **Quickpass** or **1password** installed, please note that the listed program names may not match exactly to the program names in the database. Be sure to include the computer names, operating system, program names and program version in the PD output.</font>

# %%
# %%sql
#
# SELECT c.computer_name, c.operating_system, i.program_name, i.program_version
# FROM computers c
# INNER JOIN installed_programs i ON c.computer_name = i.computer_name
# WHERE (
#       i.program_name LIKE '/Applications/Bitwarden.app'
#       OR i.program_name LIKE 'Quickpass'
#       OR i.program_name LIKE '1password'
# )
# AND   c.computer_type NOT LIKE 'Admin'
# ORDER BY i.program_name;
# Out:
#  * sqlite:///cms.sqlite
# Done.
# [('Testers-Mac-mini', 'macOS 14.0 (23A344)', '/Applications/Bitwarden.app', '2023.1.1'),
#  ('Testers-Mini', 'macOS 13.3.1 (a) (22E772610a)', '/Applications/Bitwarden.app', '2023.1.1'),
#  ('ZPPLAINCORP-MAC', 'macOS 13.2 (22D49)', '/Applications/Bitwarden.app', '2023.1.1'),
#  ('PLAINCORP-1012', 'Microsoft Windows 11 Pro', '1password', '2.7.4'),
#  ('PLAINCORP-1014', 'Microsoft Windows 11 Business', '1password', '2.7.4'),
#  ('DESKTOP-O23A1M7', 'Microsoft Windows 11 Pro', 'Quickpass', '15.0.21225.01'),
#  ('DESKTOP-O23A1M7', 'Microsoft Windows 11 Pro', 'Quickpass', '15.0.21225.01'),
#  ('DESKTOP-O23A1M7', 'Microsoft Windows 11 Pro', 'Quickpass', '15.0.21225.01'),
#  ('DESKTOP-O23A1M7', 'Microsoft Windows 11 Pro', 'Quickpass', '15.0.21225.01'),
#  ('DESKTOP-O23A1M7', 'Microsoft Windows 11 Pro', 'Quickpass', '15.0.21225.01'),
#  ('DESKTOP-O23A1M7', 'Microsoft Windows 11 Pro', 'Quickpass', '15.0.21225.01'),
#  ('LAPTOP-55433J3D', 'Microsoft Windows 11 Business', 'Quickpass', '15.0.21225.01'),
#  ('LAPTOP-55433J3D', 'Microsoft Windows 11 Business', 'Quickpass', '15.0.21225.01'),
#  ('PLAINCORP-1014', 'Microsoft Windows 11 Business', 'Quickpass', '15.0.18198.01'),
#  ('PLAINCORP-1014', 'Microsoft Windows 11 Business', 'Quickpass', '15.0.18198.01'),
#  ('PLAINCORP-DRAKE', 'Microsoft Windows 11 Pro', 'Quickpass', '15.0.21225.01'),
#  ('PLAINCORP-DRAKE', 'Microsoft Windows 11 Pro', 'Quickpass', '15.0.21225.01'),
#  ('PLAINCORP-WILL-P', 'Microsoft Windows 11 Business', 'Quickpass', '15.0.21225.01'),
#  ('PLAINCORP-WILL-P', 'Microsoft Windows 11 Business', 'Quickpass', '15.0.21225.01'),
#  ('WINDEV2303EVAL', 'Microsoft Windows 11 Enterprise Evaluation', 'Quickpass', '15.0.21225.01'),
#  ('WINDEV2303EVAL', 'Microsoft Windows 11 Enterprise Evaluation', 'Quickpass', '15.0.21225.01')]

# %%
query = '''
SELECT c.computer_name, c.operating_system, i.program_name, i.program_version
FROM computers c
INNER JOIN installed_programs i ON c.computer_name = i.computer_name
WHERE (
      i.program_name LIKE '/Applications/Bitwarden.app'
      OR i.program_name LIKE 'Quickpass'
      OR i.program_name LIKE '1password'
)
AND   c.computer_type NOT LIKE 'Admin'
ORDER BY i.program_name;
'''

df = pd.read_sql(query, conn)
df.head()
# Out:
#       computer_name               operating_system  \
# 0  Testers-Mac-mini            macOS 14.0 (23A344)
# 1      Testers-Mini  macOS 13.3.1 (a) (22E772610a)
# 2   ZPPLAINCORP-MAC             macOS 13.2 (22D49)
# 3    PLAINCORP-1012       Microsoft Windows 11 Pro
# 4    PLAINCORP-1014  Microsoft Windows 11 Business
#
#                   program_name program_version
# 0  /Applications/Bitwarden.app        2023.1.1
# 1  /Applications/Bitwarden.app        2023.1.1
# 2  /Applications/Bitwarden.app        2023.1.1
# 3                    1password           2.7.4
# 4                    1password           2.7.4

# %% [markdown]
# <font size='5'>2b. Report the latest version of each program and how many computers have said programs installed.</font>

# %%
# %%sql
#
# SELECT i.program_name, i.program_version, count(c.computer_name) AS number_of_computers
# FROM installed_programs i
# LEFT JOIN computers c ON i.computer_name = c.computer_name
# GROUP BY program_name
# HAVING i.program_name = (
#     SELECT MAX(i.program_name) FROM installed_programs i2 WHERE i2.program_name = i.program_name
# );
# Out:
#  * sqlite:///cms.sqlite
# Done.
# [('/Applications/Bitwarden.app', '2023.1.1', 3),
#  ('/Applications/Firefox.app', '114.0.1', 2),
#  ('/Applications/GitHub Desktop.app', '3.3.3', 2),
#  ('/Applications/Google Chrome.app', '117.0.5938.149', 2),
#  ('/Applications/JetBrains Toolbox.app', '1.27.2.13801', 2),
#  ('/Applications/Microsoft Outlook.app', '16.69.1', 2),
#  ('/Applications/Microsoft Teams.app', '1.00.624065', 2),
#  ('/Applications/Obsidian.app', '1.1.9', 2),
#  ('/Applications/Postman.app', '10.13.0', 2),
#  ('/Applications/Safari.app', '17.0', 2),
#  ('/Applications/Splashtop Streamer.app', '3.5.8.1', 1),
#  ('/Applications/Visual Studio Code.app', '1.82.2', 2),
#  ('/Applications/Visual Studio.app', '17.4.3.21', 2),
#  ('/Applications/Xamarin Profiler.app', '1.8.0.19', 2),
#  ('/Applications/Xcode.app', '14.2', 2),
#  ('/Applications/zoom.us.app', '5.13.7 (15481)', 2),
#  ('1password', '2.7.4', 2),
#  ('7-Zip 22.01 (x64 edition)', '22.01.00.0', 1),
#  ('AMD DVR64', '1.0.2', 3),
#  ('AMD Settings', '2023.0412.2328.1963', 3),
#  ('AMD WVR64', '1.0.2', 3),
#  ('API Monitor v2 (Alpha)', '2.13.0', 1),
#  ('AWS Command Line Interface v2', '2.15.6.0', 5),
#  ('Active Directory Authentication Library for SQL Server', '15.0.1300.359', 2),
#  ('Adobe Acrobat (64-bit)', '23.001.20174', 4),
#  ('Adobe Acrobat DC', '22.002.20212', 2),
#  ('Adobe Acrobat DC (64-bit)', '21.011.20039', 3),
#  ('Adobe Refresh Manager', '1.8.0', 8),
#  ('AdoptOpenJDK JRE with Hotspot 11.0.7.10 (x64)', '11.0.7.10', 1),
#  ('Amazon Corretto (x64)', '11.0.19.7', 1),
#  ('Amazon Corretto 8 (x86)', '1.8.0.372', 1),
#  ('Application Verifier x64 External Package', '10.1.22000.832', 11),
#  ('Application Verifier x64 External Package (DesktopEditions)', '10.1.22621.755', 4),
#  ('Application Verifier x64 External Package (OnecoreUAP)', '10.1.22621.755', 4),
#  ('Bing Bar', '7.1.355.0', 1),
#  ('Bonjour', '3.0.0.10', 1),
#  ('Bonjour SDK', '3.0.0.10', 1),
#  ('Branding64', '1.00.0008', 3),
#  ('Camtasia 2021', '21.0.4.31371', 1),
#  ('DiagnosticsHub_CollectionService', '17.3.32601', 12),
#  ('Documentation Manager', '22.120.1.9', 3),
#  ('Dolby Atmos Windows API SDK', '1.1.9.33', 1),
#  ('Dolby Atmos Windows APP', '1.1.8.23', 1),
#  ('Dynamic Application Loader Host Interface Service', '1.0.0.0', 3),
#  ('Eclipse Temurin JDK with Hotspot 17.0.5+8 (x64)', '17.0.5.8', 1),
#  ('Eclipse Temurin JDK with Hotspot 17.0.7+7 (x64)', '17.0.7.7', 4),
#  ('Eclipse Temurin JDK with Hotspot 8u372-b07 (x64)', '8.0.372.7', 4),
#  ('Eclipse Temurin JRE with Hotspot 11.0.19+7 (x64)', '11.0.19.7', 1),
#  ('Eclipse Temurin JRE with Hotspot 8u362-b09 (x86)', '8.0.362.9', 4),
#  ('Eclipse Temurin JRE with Hotspot 8u372-b07 (x64)', '8.0.372.7', 1),
#  ('Elgato Camera Hub', '1.5.2.905', 2),
#  ('Elliptic Virtual Lock Sensor Service', '3.1.40715.3', 1),
#  ('Enable UEFI SecureBoot Tool', '10.1.22621.382', 3),
#  ('Entity Framework 6.2.0 Tools  for Visual Studio 2019', '6.2.0.0', 2),
#  ('Entity Framework 6.2.0 Tools  for Visual Studio 2022', '6.2.0.0', 10),
#  ('Git Extensions 4.2.1.17611', '4.2.1.17611', 1),
#  ('GitHub CLI', '2.30.0', 1),
#  ('GitHub Desktop Deployment Tool', '3.1.2.0', 1),
#  ('GoTo Opener', '1.0.551', 19),
#  ('Google Chrome', '106.0.5249.91', 3),
#  ('Google Update Helper', '1.3.101.0', 1),
#  ('HOTKEY', '1.0.1', 35),
#  ('HP Officejet 4620 series Basic Device Software', '28.1.1307.0', 1),
#  ('HP Officejet 4620 series Help', '6.0.0', 1),
#  ('HP Officejet 4620 series Product Improvement Study', '28.1.1307.0', 1),
#  ('HP Update', '5.003.003.001', 1),
#  ('IIS 10.0 Express', '10.0.07728', 12),
#  ('Intel(R) Chipset Device Software', '10.1.19199.8340', 3),
#  ('Intel(R) Extreme Tuning Utility', '7.11.0.42', 3),
#  ('Intel(R) ME WMI Provider', '1.0.0.0', 3),
#  ('Intel(R) Management Engine Components', '1.0.0.0', 5),
#  ('Intel(R) Management Engine Driver', '1.0.0.0', 4),
#  ('Intel(R) Trusted Connect Service Client x64', '1.63.1155.1', 1),
#  ('Intel(R) Trusted Connect Service Client x86', '1.63.1155.1', 1),
#  ('Intel(R) Wireless Bluetooth(R)', '22.160.0.3', 3),
#  ('Intel® PROSet/Wireless WiFi Software', '21.30.2.3277', 1),
#  ('Java(TM) SE Development Kit 19.0.1 (64-bit)', '19.0.1.0', 1),
#  ('JetBrains ETW Host Service (x64)', '16.37.0', 11),
#  ('Kits Configuration Installer', '10.1.22000.832', 10),
#  ('LibreOffice 7.5.2.2', '7.5.2.2', 3),
#  ('LibreOffice 7.5.3.2', '7.5.3.2', 1),
#  ('MSI Development Tools', '10.1.22000.832', 15),
#  ('Microsoft Azure Authoring Tools - v2.9.7', '2.9.8999.45', 7),
#  ('Microsoft Azure Compute Emulator - v2.9.7', '2.9.8999.43', 7),
#  ('Microsoft Azure Information Protection', '2.16.73.0', 1),
#  ('Microsoft Azure PowerShell - April 2018', '5.7.0.18831', 6),
#  ('Microsoft Azure Storage Emulator - v5.10', '5.10.19227.2113', 2),
#  ('Microsoft Build of OpenJDK with Hotspot 11.0.12+7 (x64)', '11.0.12.7', 3),
#  ('Microsoft Build of OpenJDK with Hotspot 11.0.16.1+1 (x64)', '11.0.16.101', 1),
#  ('Microsoft Command Line Utilities 15 for SQL Server', '15.0.1300.359', 12),
#  ('Microsoft HTML Help Workshop Package', '4.74.8702', 1),
#  ('Microsoft Intune Management Extension', '1.73.202.0', 15),
#  ('Microsoft Mouse and Keyboard Center', '14.41.137.0', 1),
#  ('Microsoft ODBC Driver 17 for SQL Server', '17.7.2.1', 12),
#  ('Microsoft S/MIME Control for Outlook on the web for Edge/Chrome', '15.21.18833', 2),
#  ('Microsoft SQL Server 2016 LocalDB', '13.1.4001.0', 2),
#  ('Microsoft SQL Server 2019 LocalDB', '15.0.4153.1', 11),
#  ('Microsoft Silverlight', '5.1.50907.0', 1),
#  ('Microsoft System CLR Types for SQL Server 2019', '15.0.2000.5', 11),
#  ('Microsoft System CLR Types for SQL Server 2019 CTP2.2', '15.0.1200.24', 3),
#  ('Microsoft Teams', '1.4.0.22976', 30),
#  ('Microsoft TestPlatform SDK Local Feed', '17.0.0.5175695', 12),
#  ('Microsoft UniversalWindowsPlatform SDK', '15.9.16', 7),
#  ('Microsoft Update Health Tools', '3.72.0.0', 35),
#  ('Microsoft VC++ redistributables repacked.', '12.0.0.0', 2),
#  ('Microsoft Visual C++ 2008 Redistributable - x64 9.0.30729.6161', '9.0.30729.6161', 3),
#  ('Microsoft Visual C++ 2008 Redistributable - x86 9.0.30729.6161', '9.0.30729.6161', 4),
#  ('Microsoft Visual C++ 2010  x64 Redistributable - 10.0.30319', '10.0.30319', 2),
#  ('Microsoft Visual C++ 2010  x64 Redistributable - 10.0.40219', '10.0.40219', 3),
#  ('Microsoft Visual C++ 2010  x86 Redistributable - 10.0.30319', '10.0.30319', 2),
#  ('Microsoft Visual C++ 2010  x86 Redistributable - 10.0.40219', '10.0.40219', 3),
#  ('Microsoft Visual C++ 2012 x64 Additional Runtime - 11.0.61030', '11.0.61030', 4),
#  ('Microsoft Visual C++ 2012 x64 Minimum Runtime - 11.0.61030', '11.0.61030', 4),
#  ('Microsoft Visual C++ 2012 x86 Additional Runtime - 11.0.61030', '11.0.61030', 4),
#  ('Microsoft Visual C++ 2012 x86 Minimum Runtime - 11.0.61030', '11.0.61030', 4),
#  ('Microsoft Visual C++ 2013 x64 Additional Runtime - 12.0.21005', '12.0.21005', 2),
#  ('Microsoft Visual C++ 2013 x64 Additional Runtime - 12.0.40664', '12.0.40664', 5),
#  ('Microsoft Visual C++ 2013 x64 Minimum Runtime - 12.0.21005', '12.0.21005', 2),
#  ('Microsoft Visual C++ 2013 x64 Minimum Runtime - 12.0.40664', '12.0.40664', 5),
#  ('Microsoft Visual C++ 2013 x86 Additional Runtime - 12.0.21005', '12.0.21005', 3),
#  ('Microsoft Visual C++ 2013 x86 Additional Runtime - 12.0.40664', '12.0.40664', 5),
#  ('Microsoft Visual C++ 2013 x86 Minimum Runtime - 12.0.21005', '12.0.21005', 3),
#  ('Microsoft Visual C++ 2013 x86 Minimum Runtime - 12.0.40664', '12.0.40664', 5),
#  ('Microsoft Visual C++ 2017 x64 Additional Runtime - 14.11.25325', '14.11.25325', 1),
#  ('Microsoft Visual C++ 2017 x64 Minimum Runtime - 14.11.25325', '14.11.25325', 1),
#  ('Microsoft Visual C++ 2019 X64 Additional Runtime - 14.26.28720', '14.26.28720', 2),
#  ('Microsoft Visual C++ 2019 X64 Additional Runtime - 14.29.30037', '14.29.30037', 2),
#  ('Microsoft Visual C++ 2019 X64 Debug Runtime - 14.29.30139', '14.29.30139', 2),
#  ('Microsoft Visual C++ 2019 X64 Minimum Runtime - 14.26.28720', '14.26.28720', 2),
#  ('Microsoft Visual C++ 2019 X64 Minimum Runtime - 14.29.30037', '14.29.30037', 2),
#  ('Microsoft Visual C++ 2019 X86 Additional Runtime - 14.23.27820', '14.23.27820', 1),
#  ('Microsoft Visual C++ 2019 X86 Additional Runtime - 14.29.30037', '14.29.30037', 2),
#  ('Microsoft Visual C++ 2019 X86 Debug Runtime - 14.29.30139', '14.29.30139', 2),
#  ('Microsoft Visual C++ 2019 X86 Minimum Runtime - 14.23.27820', '14.23.27820', 1),
#  ('Microsoft Visual C++ 2019 X86 Minimum Runtime - 14.29.30037', '14.29.30037', 2),
#  ('Microsoft Visual C++ 2022 X64 Additional Runtime - 14.30.30704', '14.30.30704', 5),
#  ('Microsoft Visual C++ 2022 X64 Additional Runtime - 14.32.31326', '14.32.31326', 4),
#  ('Microsoft Visual C++ 2022 X64 Additional Runtime - 14.32.31332', '14.32.31332', 1),
#  ('Microsoft Visual C++ 2022 X64 Additional Runtime - 14.34.31931', '14.34.31931', 2),
#  ('Microsoft Visual C++ 2022 X64 Additional Runtime - 14.34.31938', '14.34.31938', 5),
#  ('Microsoft Visual C++ 2022 X64 Additional Runtime - 14.36.32532', '14.36.32532', 3),
#  ('Microsoft Visual C++ 2022 X64 Additional Runtime - 14.38.33130', '14.38.33130', 1),
#  ('Microsoft Visual C++ 2022 X64 Debug Runtime - 14.34.31931', '14.34.31931', 1),
#  ('Microsoft Visual C++ 2022 X64 Debug Runtime - 14.34.31938', '14.34.31938', 5),
#  ('Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.30.30704', '14.30.30704', 5),
#  ('Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.32.31326', '14.32.31326', 4),
#  ('Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.32.31332', '14.32.31332', 1),
#  ('Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.34.31931', '14.34.31931', 2),
#  ('Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.34.31938', '14.34.31938', 5),
#  ('Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.36.32532', '14.36.32532', 3),
#  ('Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.38.33130', '14.38.33130', 1),
#  ('Microsoft Visual C++ 2022 X86 Additional Runtime - 14.30.30704', '14.30.30704', 1),
#  ('Microsoft Visual C++ 2022 X86 Additional Runtime - 14.32.31326', '14.32.31326', 4),
#  ('Microsoft Visual C++ 2022 X86 Additional Runtime - 14.34.31931', '14.34.31931', 3),
#  ('Microsoft Visual C++ 2022 X86 Additional Runtime - 14.34.31938', '14.34.31938', 5),
#  ('Microsoft Visual C++ 2022 X86 Additional Runtime - 14.36.32532', '14.36.32532', 2),
#  ('Microsoft Visual C++ 2022 X86 Additional Runtime - 14.38.33130', '14.38.33130', 1),
#  ('Microsoft Visual C++ 2022 X86 Debug Runtime - 14.34.31931', '14.34.31931', 1),
#  ('Microsoft Visual C++ 2022 X86 Debug Runtime - 14.34.31938', '14.34.31938', 5),
#  ('Microsoft Visual C++ 2022 X86 Minimum Runtime - 14.30.30704', '14.30.30704', 1),
#  ('Microsoft Visual C++ 2022 X86 Minimum Runtime - 14.32.31326', '14.32.31326', 4),
#  ('Microsoft Visual C++ 2022 X86 Minimum Runtime - 14.34.31931', '14.34.31931', 3),
#  ('Microsoft Visual C++ 2022 X86 Minimum Runtime - 14.34.31938', '14.34.31938', 5),
#  ('Microsoft Visual C++ 2022 X86 Minimum Runtime - 14.36.32532', '14.36.32532', 2),
#  ('Microsoft Visual C++ 2022 X86 Minimum Runtime - 14.38.33130', '14.38.33130', 1),
#  ('Microsoft Visual Studio 2010 Tools for Office Runtime (x64)', '10.0.60729', 1),
#  ('Microsoft Visual Studio Setup Configuration', '3.5.2150.18781', 13),
#  ('Microsoft Visual Studio Setup WMI Provider', '3.5.2150.18781', 13),
#  ('Microsoft Web Deploy 4.0', '10.0.7225', 11),
#  ('Microsoft Windows Desktop Runtime - 3.1.31 (x64)', '24.124.31813', 1),
#  ('Microsoft Windows Desktop Runtime - 3.1.31 (x86)', '24.124.31813', 1),
#  ('Microsoft Windows Desktop Runtime - 3.1.32 (x64)', '24.192.31915', 1),
#  ('Microsoft Windows Desktop Runtime - 5.0.17 (x64)', '40.68.31219', 7),
#  ('Microsoft Windows Desktop Runtime - 5.0.17 (x86)', '40.68.31219', 1),
#  ('Microsoft Windows Desktop Runtime - 6.0.1 (x64)', '48.7.32738', 1),
#  ('Microsoft Windows Desktop Runtime - 6.0.1 (x86)', '48.7.32738', 1),
#  ('Microsoft Windows Desktop Runtime - 6.0.10 (x64)', '48.43.48870', 1),
#  ('Microsoft Windows Desktop Runtime - 6.0.10 (x86)', '48.43.48870', 1),
#  ('Microsoft Windows Desktop Runtime - 6.0.11 (x64)', '48.47.50419', 1),
#  ('Microsoft Windows Desktop Runtime - 6.0.11 (x86)', '48.47.50419', 1),
#  ('Microsoft Windows Desktop Runtime - 6.0.13 (x64)', '48.55.53270', 2),
#  ('Microsoft Windows Desktop Runtime - 6.0.13 (x86)', '48.55.53270', 2),
#  ('Microsoft Windows Desktop Runtime - 6.0.15 (x64)', '48.63.56729', 2),
#  ('Microsoft Windows Desktop Runtime - 6.0.15 (x86)', '48.63.56729', 1),
#  ('Microsoft Windows Desktop Runtime - 6.0.16 (x64)', '48.67.58484', 4),
#  ('Microsoft Windows Desktop Runtime - 6.0.16 (x86)', '48.67.58484', 4),
#  ('Microsoft Windows Desktop Runtime - 6.0.18 (x64)', '48.75.61602', 1),
#  ('Microsoft Windows Desktop Runtime - 6.0.18 (x86)', '48.75.61602', 1),
#  ('Microsoft Windows Desktop Runtime - 6.0.22 (x64)', '48.88.914', 1),
#  ('Microsoft Windows Desktop Runtime - 6.0.25 (x64)', '48.100.4037', 1),
#  ('Microsoft Windows Desktop Runtime - 6.0.25 (x86)', '48.100.4037', 1),
#  ('Microsoft Windows Desktop Runtime - 6.0.9 (x64)', '48.39.47171', 4),
#  ('Microsoft Windows Desktop Runtime - 7.0.0 (x64)', '56.3.50353', 1),
#  ('Microsoft Windows Desktop Runtime - 7.0.11 (x64)', '56.44.917', 1),
#  ('Microsoft Windows Desktop Runtime - 7.0.2 (x64)', '56.11.53361', 4),
#  ('Microsoft Windows Desktop Runtime - 7.0.2 (x86)', '56.11.53361', 2),
#  ('Microsoft Windows Desktop Runtime - 7.0.4 (x64)', '56.19.56739', 2),
#  ('Microsoft Windows Desktop Runtime - 7.0.4 (x86)', '56.19.56739', 1),
#  ('Microsoft Windows Desktop Runtime - 7.0.5 (x64)', '56.23.58485', 5),
#  ('Microsoft Windows Desktop Runtime - 7.0.5 (x86)', '56.23.58485', 4),
#  ('Microsoft Windows Desktop Runtime - 7.0.7 (x64)', '56.31.61651', 1),
#  ('Microsoft Windows Desktop Runtime - 7.0.7 (x86)', '56.31.61651', 1),
#  ('Microsoft Windows Desktop Runtime - 8.0.0 (x64)', '64.0.5329', 1),
#  ('Microsoft Windows Desktop Runtime - 8.0.0 (x86)', '64.0.5329', 1),
#  ('Microsoft Windows Desktop Runtime - 8.0.0 Preview 3 (x64)', '64.3.58497', 2),
#  ('Microsoft Windows Desktop Targeting Pack - 3.1.0 (x64)', '24.64.28315', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 5.0.0 (x64)', '40.0.29420', 2),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.0 (x64)', '48.3.31217', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.10 (x64)', '48.43.48870', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.10 (x86)', '48.43.48870', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.11 (x64)', '48.47.50419', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.13 (x64)', '48.55.53270', 2),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.13 (x86)', '48.55.53270', 2),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.15 (x64)', '48.63.56729', 2),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.15 (x86)', '48.63.56729', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.16 (x64)', '48.67.58484', 4),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.16 (x86)', '48.67.58484', 4),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.18 (x64)', '48.75.61602', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.18 (x86)', '48.75.61602', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.22 (x64)', '48.88.914', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.25 (x64)', '48.100.4037', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.25 (x86)', '48.100.4037', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.9 (x64)', '48.39.47171', 3),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.11 (x64)', '56.44.917', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.2 (x64)', '56.11.53361', 4),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.2 (x86)', '56.11.53361', 2),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.4 (x64)', '56.19.56739', 2),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.4 (x86)', '56.19.56739', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.5 (x64)', '56.23.58485', 5),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.5 (x86)', '56.23.58485', 4),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.7 (x64)', '56.31.61651', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.7 (x86)', '56.31.61651', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 8.0.0 (x64)', '64.0.5329', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 8.0.0 (x86)', '64.0.5329', 1),
#  ('Microsoft Windows Desktop Targeting Pack - 8.0.0 Preview 3 (x64)', '64.3.58497', 2),
#  ('Microsoft.Android.Ref.31 (x64)', '32.0.476.0', 1),
#  ('Microsoft.Android.Ref.33 (x64)', '33.0.46.0', 2),
#  ('Microsoft.Android.Runtime.31.android-arm (x64)', '32.0.476.0', 1),
#  ('Microsoft.Android.Runtime.31.android-arm64 (x64)', '32.0.476.0', 1),
#  ('Microsoft.Android.Runtime.31.android-x64 (x64)', '32.0.476.0', 1),
#  ('Microsoft.Android.Runtime.31.android-x86 (x64)', '32.0.476.0', 1),
#  ('Microsoft.Android.Runtime.33.android-arm (x64)', '33.0.46.0', 2),
#  ('Microsoft.Android.Runtime.33.android-arm64 (x64)', '33.0.46.0', 2),
#  ('Microsoft.Android.Runtime.33.android-x64 (x64)', '33.0.46.0', 2),
#  ('Microsoft.Android.Runtime.33.android-x86 (x64)', '33.0.46.0', 2),
#  ('Microsoft.Android.Sdk.Windows (x64)', '33.0.46.0', 5),
#  ('Microsoft.MacCatalyst.Ref (x64)', '16.4.7054.0', 3),
#  ('Microsoft.MacCatalyst.Runtime.maccatalyst-arm64 (x64)', '16.4.7054.0', 3),
#  ('Microsoft.MacCatalyst.Runtime.maccatalyst-x64 (x64)', '16.4.7054.0', 3),
#  ('Microsoft.MacCatalyst.Sdk (x64)', '16.4.7054.0', 5),
#  ('Microsoft.MacCatalyst.Templates (x64)', '16.4.7054.0', 3),
#  ('Microsoft.Maui.Controls.Ref.android (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Controls.Ref.any (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Controls.Ref.ios (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Controls.Ref.maccatalyst (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Controls.Ref.win (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Controls.Runtime.android (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Controls.Runtime.any (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Controls.Runtime.ios (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Controls.Runtime.maccatalyst (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Controls.Runtime.win (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Core.Ref.android (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Core.Ref.any (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Core.Ref.ios (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Core.Ref.maccatalyst (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Core.Ref.win (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Core.Runtime.android (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Core.Runtime.any (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Core.Runtime.ios (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Core.Runtime.maccatalyst (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Core.Runtime.win (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Dependencies (x64)', '6.0.541.0', 1),
#  ('Microsoft.Maui.Essentials.Ref.android (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Essentials.Ref.any (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Essentials.Ref.ios (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Essentials.Ref.maccatalyst (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Essentials.Ref.win (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Essentials.Runtime.android (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Essentials.Runtime.any (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Essentials.Runtime.ios (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Essentials.Runtime.maccatalyst (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Essentials.Runtime.win (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Extensions (x64)', '6.0.541.0', 1),
#  ('Microsoft.Maui.Graphics (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Graphics.Win2D.WinUI (x64)', '6.0.501.0', 1),
#  ('Microsoft.Maui.Graphics.Win2D.WinUI.Desktop (x64)', '7.0.86.0', 2),
#  ('Microsoft.Maui.Resizetizer.Sdk (x64)', '7.0.86.0', 3),
#  ('Microsoft.Maui.Sdk (x64)', '7.0.86.0', 5),
#  ('Microsoft.iOS.Ref (x64)', '16.4.7054.0', 3),
#  ('Microsoft.iOS.Runtime.ios-arm (x64)', '16.4.7054.0', 3),
#  ('Microsoft.iOS.Runtime.ios-arm64 (x64)', '16.4.7054.0', 3),
#  ('Microsoft.iOS.Runtime.iossimulator-arm64 (x64)', '16.4.7054.0', 3),
#  ('Microsoft.iOS.Runtime.iossimulator-x64 (x64)', '16.4.7054.0', 3),
#  ('Microsoft.iOS.Runtime.iossimulator-x86 (x64)', '16.4.7054.0', 3),
#  ('Microsoft.iOS.Sdk (x64)', '16.4.7054.0', 5),
#  ('Microsoft.iOS.Templates (x64)', '16.4.7054.0', 3),
#  ('Microsoft.iOS.Windows.Sdk (x64)', '16.4.7054.0', 5),
#  ('Minimal WLPC Content', '10.1.22621.382', 3),
#  ('Network Monitor Parsers', '10.1.22621.382', 3),
#  ('OA3Tool', '10.1.22621.382', 3),
#  ('OEM Test Certificates (OnecoreUAP)', '10.1.22621.382', 3),
#  ('Office 16 Click-to-Run Extensibility Component', '16.0.14827.20198', 25),
#  ('Office 16 Click-to-Run Extensibility Component 64-bit Registration', '16.0.16924.20124', 1),
#  ('Office 16 Click-to-Run Licensing Component', '16.0.14827.20198', 25),
#  ('Office 16 Click-to-Run Localization Component', '16.0.13127.20616', 5),
#  ('OneCoreUap_ApiValidator_WDK_Kit_Content', '10.1.22621.382', 3),
#  ('OneCoreUap_WDTF_Headers_and_Libs_Kit_Content', '10.1.22621.382', 3),
#  ('OpenSSH', '8.9.1.0', 1),
#  ('Oracle VM VirtualBox 7.0.12', '7.0.12', 1),
#  ('Oracle VM VirtualBox 7.0.6', '7.0.6', 1),
#  ('Oracle VM VirtualBox 7.0.8', '7.0.8', 3),
#  ('PDF Suite 2020', '18.0.26.4880', 1),
#  ('PDF Suite 2020 OCR TESS Module', '18.0.26.4880', 1),
#  ('PowerShell 7-x64', '7.3.8.0', 4),
#  ('PowerToys (Preview)', '0.70.0', 1),
#  ('PuTTY release 0.75 (64-bit)', '0.75.0.0', 1),
#  ('PuTTY release 0.76 (64-bit)', '0.76.0.0', 1),
#  ('PuTTY release 0.78 (64-bit)', '0.78.0.0', 5),
#  ('Puppet (64-bit)', '3.8.7', 1),
#  ('Python 2.7.13 (64-bit)', '2.7.13150', 4),
#  ('Python 3.10.8 Add to Path (64-bit)', '3.10.8150.0', 1),
#  ('Python 3.10.8 Core Interpreter (64-bit)', '3.10.8150.0', 1),
#  ('Python 3.10.8 Development Libraries (64-bit)', '3.10.8150.0', 1),
#  ('Python 3.10.8 Documentation (64-bit)', '3.10.8150.0', 1),
#  ('Python 3.10.8 Executables (64-bit)', '3.10.8150.0', 1),
#  ('Python 3.10.8 Standard Library (64-bit)', '3.10.8150.0', 1),
#  ('Python 3.10.8 Tcl/Tk Support (64-bit)', '3.10.8150.0', 1),
#  ('Python 3.10.8 Test Suite (64-bit)', '3.10.8150.0', 1),
#  ('Python 3.10.8 Utility Scripts (64-bit)', '3.10.8150.0', 1),
#  ('Python 3.10.8 pip Bootstrap (64-bit)', '3.10.8150.0', 1),
#  ('Python 3.11.0 Add to Path (64-bit)', '3.11.150.0', 1),
#  ('Python 3.11.0 Core Interpreter (64-bit)', '3.11.150.0', 1),
#  ('Python 3.11.0 Development Libraries (64-bit)', '3.11.150.0', 1),
#  ('Python 3.11.0 Documentation (64-bit)', '3.11.150.0', 1),
#  ('Python 3.11.0 Executables (64-bit)', '3.11.150.0', 1),
#  ('Python 3.11.0 Standard Library (64-bit)', '3.11.150.0', 1),
#  ('Python 3.11.0 Tcl/Tk Support (64-bit)', '3.11.150.0', 1),
#  ('Python 3.11.0 Test Suite (64-bit)', '3.11.150.0', 1),
#  ('Python 3.11.0 Utility Scripts (64-bit)', '3.11.150.0', 1),
#  ('Python 3.11.0 pip Bootstrap (64-bit)', '3.11.150.0', 1),
#  ('Python 3.11.3 Add to Path (64-bit)', '3.11.3150.0', 1),
#  ('Python 3.11.3 Core Interpreter (32-bit)', '3.11.3150.0', 3),
#  ('Python 3.11.3 Core Interpreter (64-bit)', '3.11.3150.0', 5),
#  ('Python 3.11.3 Development Libraries (32-bit)', '3.11.3150.0', 3),
#  ('Python 3.11.3 Development Libraries (64-bit)', '3.11.3150.0', 5),
#  ('Python 3.11.3 Documentation (32-bit)', '3.11.3150.0', 3),
#  ('Python 3.11.3 Documentation (64-bit)', '3.11.3150.0', 5),
#  ('Python 3.11.3 Executables (32-bit)', '3.11.3150.0', 3),
#  ('Python 3.11.3 Executables (64-bit)', '3.11.3150.0', 5),
#  ('Python 3.11.3 Standard Library (32-bit)', '3.11.3150.0', 3),
#  ('Python 3.11.3 Standard Library (64-bit)', '3.11.3150.0', 5),
#  ('Python 3.11.3 Tcl/Tk Support (32-bit)', '3.11.3150.0', 3),
#  ('Python 3.11.3 Tcl/Tk Support (64-bit)', '3.11.3150.0', 5),
#  ('Python 3.11.3 Test Suite (32-bit)', '3.11.3150.0', 3),
#  ('Python 3.11.3 Test Suite (64-bit)', '3.11.3150.0', 5),
#  ('Python 3.11.3 Utility Scripts (32-bit)', '3.11.3150.0', 3),
#  ('Python 3.11.3 Utility Scripts (64-bit)', '3.11.3150.0', 5),
#  ('Python 3.11.3 pip Bootstrap (32-bit)', '3.11.3150.0', 3),
#  ('Python 3.11.3 pip Bootstrap (64-bit)', '3.11.3150.0', 5),
#  ('Python 3.11.4 Core Interpreter (64-bit)', '3.11.4150.0', 1),
#  ('Python 3.11.4 Development Libraries (64-bit)', '3.11.4150.0', 1),
#  ('Python 3.11.4 Documentation (64-bit)', '3.11.4150.0', 1),
#  ('Python 3.11.4 Executables (64-bit)', '3.11.4150.0', 1),
#  ('Python 3.11.4 Standard Library (64-bit)', '3.11.4150.0', 1),
#  ('Python 3.11.4 Tcl/Tk Support (64-bit)', '3.11.4150.0', 1),
#  ('Python 3.11.4 Test Suite (64-bit)', '3.11.4150.0', 1),
#  ('Python 3.11.4 Utility Scripts (64-bit)', '3.11.4150.0', 1),
#  ('Python 3.11.4 pip Bootstrap (64-bit)', '3.11.4150.0', 1),
#  ('Python 3.9.7 Core Interpreter (64-bit symbols)', '3.9.7150.0', 1),
#  ('Python 3.9.7 Core Interpreter (64-bit)', '3.9.7150.0', 1),
#  ('Python 3.9.7 Development Libraries (64-bit)', '3.9.7150.0', 1),
#  ('Python 3.9.7 Documentation (64-bit)', '3.9.7150.0', 1),
#  ('Python 3.9.7 Executables (64-bit symbols)', '3.9.7150.0', 1),
#  ('Python 3.9.7 Executables (64-bit)', '3.9.7150.0', 1),
#  ('Python 3.9.7 Standard Library (64-bit symbols)', '3.9.7150.0', 1),
#  ('Python 3.9.7 Standard Library (64-bit)', '3.9.7150.0', 1),
#  ('Python 3.9.7 Tcl/Tk Support (64-bit symbols)', '3.9.7150.0', 1),
#  ('Python 3.9.7 Tcl/Tk Support (64-bit)', '3.9.7150.0', 1),
#  ('Python 3.9.7 Test Suite (64-bit symbols)', '3.9.7150.0', 1),
#  ('Python 3.9.7 Test Suite (64-bit)', '3.9.7150.0', 1),
#  ('Python 3.9.7 Utility Scripts (64-bit)', '3.9.7150.0', 1),
#  ('Python 3.9.7 pip Bootstrap (64-bit)', '3.9.7150.0', 1),
#  ('Python Launcher', '3.11.3150.0', 9),
#  ('QEMU guest agent', '102.10.0', 4),
#  ('Quickpass', '15.0.21225.01', 24),
#  ('Red Hat QXL controller', '0.21.2.0', 2),
#  ('SDK ARM Additions', '10.1.22000.832', 10),
#  ('SDK ARM Additions EULA', '10.1.22621.382', 3),
#  ('SDK ARM Redistributables', '10.1.22000.832', 10),
#  ('SDK Debuggers ARM', '10.1.22621.382', 3),
#  ('SRA-Tool', '3.3', 1),
#  ('Sophos AutoUpdate XG', '6.13.1014', 1),
#  ('Sophos Endpoint Agent', '2.3.150.0', 1),
#  ('Sophos Home', '5.3.7.0', 1),
#  ('Spice Agent 0.10.0-5 (64-bit)', '0.10.5', 2),
#  ('Splashtop Streamer', '3.6.0.1', 13),
#  ('Splashtop for RMM', '3.5.802.0', 1),
#  ('Thunderbolt™ Software', '17.4.80.550', 1),
#  ('TypeScript SDK', '4.3.5.0', 2),
#  ('Universal CRT Extension SDK', '10.1.22000.832', 17),
#  ('Universal CRT Headers Libraries and Sources', '10.1.22000.832', 17),
#  ('Universal CRT Redistributable', '10.1.22000.832', 19),
#  ('Universal CRT Tools x64', '10.1.22000.832', 10),
#  ('Universal CRT Tools x86', '10.1.22000.832', 10),
#  ('Universal General MIDI DLS Extension SDK', '10.1.22000.832', 15),
#  ('Update for Windows 10 for x64-based Systems (KB5001716)', '4.91.0.0', 2),
#  ('VMware Player', '17.0.0', 1),
#  ('VMware Tools', '12.1.0.20219665', 1),
#  ('VMware Workstation', '17.0.0', 5),
#  ('VS Immersive Activate Helper', '17.0.118.0', 12),
#  ('VS JIT Debugger', '17.0.118.0', 11),
#  ('VS Script Debugging Common', '17.0.118.0', 13),
#  ('VeraCrypt 1.25.9', '1.25.9', 3),
#  ('Virtio-win-driver-installer', '0.1.215', 2),
#  ('Visual C++ CRT Headers Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium ARM Base Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium ARM Base Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X64 ARM Cross Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X64 ARM Cross Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X64 Base Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X64 Base Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X64 Native Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X64 Native Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X64 X86 Cross Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X64 X86 Cross Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X86 ARM Cross Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X86 ARM Cross Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X86 Base Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X86 Base Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X86 Native Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X86 Native Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X86 X64 Cross Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools Premium X86 X64 Cross Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X64 ARM Cross Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X64 ARM Cross Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X64 Base Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X64 Base Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X64 Native Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X64 Native Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X64 X86 Cross Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X64 X86 Cross Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X86 ARM Cross Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X86 ARM Cross Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X86 Base Package', '14.0.24245', 2),
#  ('Visual C++ Compiler/Tools X86 Base Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X86 Native Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X86 Native Resource Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X86 X64 Cross Package', '14.0.24245', 1),
#  ('Visual C++ Compiler/Tools X86 X64 Cross Resource Package', '14.0.24245', 1),
#  ('Visual C++ Extra Files', '14.0.24245', 1),
#  ('Visual C++ Extra Resource Files', '14.0.24245', 1),
#  ('Visual C++ Library ATL ARM Package', '14.0.24245', 1),
#  ('Visual C++ Library ATL Headers Package', '14.0.24245', 1),
#  ('Visual C++ Library ATL Source Package', '14.0.24245', 1),
#  ('Visual C++ Library ATL X64 Package', '14.0.24245', 1),
#  ('Visual C++ Library ATL X86 Package', '14.0.24245', 1),
#  ('Visual C++ Library CRT ARM Desktop Package', '14.0.24245', 1),
#  ('Visual C++ Library CRT ARM OneCore For Desktop Package', '14.0.24245', 1),
#  ('Visual C++ Library CRT ARM Redist Package', '14.0.24245', 1),
#  ('Visual C++ Library CRT ARM Store Package', '14.0.24245', 1),
#  ('Visual C++ Library CRT ARM64 Appx Package', '14.35.32215', 10),
#  ('Visual C++ Library CRT Appx Package', '14.35.32215', 18),
#  ('Visual C++ Library CRT Appx Resource Package', '14.35.32215', 9),
#  ('Visual C++ Library CRT Desktop Appx Package', '14.35.32215', 27),
#  ('Visual C++ Library CRT Redist Resource Package', '14.0.24245', 1),
#  ('Visual C++ Library CRT Source Package', '14.0.24245', 1),
#  ('Visual C++ Library CRT X64 Desktop Package', '14.0.24245', 1),
#  ('Visual C++ Library CRT X64 OneCore For Desktop Package', '14.0.24245', 1),
#  ('Visual C++ Library CRT X64 Redist Package', '14.0.24245', 1),
#  ('Visual C++ Library CRT X64 Store Package', '14.0.24245', 1),
#  ('Visual C++ Library CRT X86 Desktop Package', '14.0.24245', 1),
#  ('Visual C++ Library CRT X86 OneCore For Desktop Package', '14.0.24245', 1),
#  ('Visual C++ Library CRT X86 Redist Package', '14.0.24245', 1),
#  ('Visual C++ Library CRT X86 Store Package', '14.0.24245', 1),
#  ('Visual C++ Library MFC Headers Package', '14.0.24245', 1),
#  ('Visual C++ Library MFC MBCS Package', '14.0.24245', 1),
#  ('Visual C++ Library MFC Source Package', '14.0.24245', 1),
#  ('Visual C++ Library MFC X64 Package', '14.0.24245', 1),
#  ('Visual C++ Library MFC X86 Package', '14.0.24245', 1),
#  ('Visual C++ Library PGO ARM Package', '14.0.24245', 1),
#  ('Visual C++ Library PGO Headers Package', '14.0.24245', 1),
#  ('Visual C++ Library PGO X64 Package', '14.0.24245', 1),
#  ('Visual C++ Library PGO X86 Package', '14.0.24245', 2),
#  ('Visual C++ MSBuild ARM Package', '14.0.24245', 1),
#  ('Visual C++ MSBuild Base Package', '14.0.24245', 1),
#  ('Visual C++ MSBuild Base Resource Package', '14.0.24245', 1),
#  ('Visual C++ MSBuild X64 Package', '14.0.24245', 1),
#  ('Visual C++ MSBuild X86 Package', '14.0.24245', 1),
#  ('WD Drive Utilities', '2.1.0.130', 1),
#  ('WinAppDeploy', '10.1.22000.832', 15),
#  ('WinRT Intellisense Desktop - Other Languages', '10.1.22000.832', 15),
#  ('WinRT Intellisense Desktop - en-us', '10.1.22000.832', 15),
#  ('WinRT Intellisense IoT - Other Languages', '10.1.22000.832', 15),
#  ('WinRT Intellisense IoT - en-us', '10.1.22000.832', 15),
#  ('WinRT Intellisense Mobile - en-us', '10.1.22000.832', 15),
#  ('WinRT Intellisense PPI - Other Languages', '10.1.22000.832', 15),
#  ('WinRT Intellisense PPI - en-us', '10.1.22000.832', 15),
#  ('WinRT Intellisense UAP - Other Languages', '10.1.22000.832', 15),
#  ('WinRT Intellisense UAP - en-us', '10.1.22000.832', 15),
#  ('Windows App Certification Kit Native Components', '10.1.22000.832', 10),
#  ('Windows App Certification Kit SupportedApiList x86', '10.1.22000.832', 10),
#  ('Windows App Certification Kit x64', '10.1.22000.832', 10),
#  ('Windows App Certification Kit x64 (OnecoreUAP)', '10.1.22621.755', 4),
#  ('Windows Content Versioned', '10.1.22621.382', 3),
#  ('Windows Debugging WDK Integration Versioned', '10.1.22621.382', 3),
#  ('Windows Deployment Image Servicing and Management Tools (OnecoreUAP)', '10.1.22621.382', 3),
#  ('Windows Desktop Extension SDK', '10.1.22000.832', 15),
#  ('Windows Desktop Extension SDK Contracts', '10.1.22000.832', 15),
#  ('Windows Driver Framework ARM Headers and Libs', '10.1.22621.382', 3),
#  ('Windows Driver Framework Headers and Libs', '10.1.22621.382', 3),
#  ('Windows Driver Kit', '10.1.22621.382', 3),
#  ('Windows Driver Kit ARM Additions', '10.1.22621.382', 3),
#  ('Windows Driver Kit ARM Binaries', '10.1.22621.382', 3),
#  ('Windows Driver Kit ARM Headers and Libs', '10.1.22621.382', 3),
#  ('Windows Driver Kit Binaries', '10.1.22621.382', 3),
#  ('Windows Driver Kit Downlevel Dev14 Content', '10.1.22621.382', 3),
#  ('Windows Driver Kit Headers and Libs', '10.1.22621.382', 3),
#  ('Windows Driver Kit Logger', '10.1.22621.382', 3),
#  ('Windows Driver Kit Root Dev17 Content', '10.1.22621.382', 3),
#  ('Windows Driver Kit SxS Content', '10.1.22621.382', 3),
#  ('Windows Driver Kit Visual Studio Dev17 Content', '10.1.22621.382', 3),
#  ('Windows Espc Package', '14.0.24245', 2),
#  ('Windows IoT Extension SDK', '10.1.22000.832', 15),
#  ('Windows IoT Extension SDK Contracts', '10.1.22000.832', 15),
#  ('Windows Mobile Extension SDK', '10.1.22000.832', 15),
#  ('Windows Mobile Extension SDK Contracts', '10.1.22000.832', 15),
#  ('Windows OEM Preproduction Desktop Policies)', '10.1.22621.382', 3),
#  ('Windows PC Health Check', '3.6.2204.08001', 3),
#  ('Windows Phone SDK 8.0 Assemblies for Visual Studio 2019', '16.0.31404', 2),
#  ('Windows SDK', '10.1.22000.832', 10),
#  ('Windows SDK ARM Desktop Tools', '10.1.22000.832', 15),
#  ('Windows SDK ARM Headers Libs Metadata', '10.1.22621.382', 3),
#  ('Windows SDK AddOn', '10.1.0.0', 10),
#  ('Windows SDK Desktop Headers arm', '10.1.22000.832', 15),
#  ('Windows SDK Desktop Headers arm64', '10.1.22000.832', 15),
#  ('Windows SDK Desktop Headers x64', '10.1.22000.832', 15),
#  ('Windows SDK Desktop Headers x86', '10.1.22000.832', 15),
#  ('Windows SDK Desktop Libs arm', '10.1.22000.832', 15),
#  ('Windows SDK Desktop Libs arm64', '10.1.22000.832', 15),
#  ('Windows SDK Desktop Libs x64', '10.1.22000.832', 15),
#  ('Windows SDK Desktop Libs x86', '10.1.22000.832', 15),
#  ('Windows SDK Desktop Tools arm64', '10.1.22000.832', 15),
#  ('Windows SDK Desktop Tools x64', '10.1.22000.832', 15),
#  ('Windows SDK Desktop Tools x86', '10.1.22000.832', 15),
#  ('Windows SDK DirectX x64 Remote', '10.1.22000.832', 10),
#  ('Windows SDK DirectX x86 Remote', '10.1.22000.832', 10),
#  ('Windows SDK EULA', '10.1.22000.832', 15),
#  ('Windows SDK Facade Windows WinMD Versioned', '10.1.22000.832', 15),
#  ('Windows SDK Modern Non-Versioned Developer Tools', '10.1.22000.832', 10),
#  ('Windows SDK Modern Versioned Developer Tools', '10.1.22000.832', 15),
#  ('Windows SDK Redistributables', '10.1.22000.832', 10),
#  ('Windows SDK Signing Tools', '10.1.22000.832', 15),
#  ('Windows SDK for Windows Store Apps', '10.1.22000.832', 10),
#  ('Windows SDK for Windows Store Apps Contracts', '10.1.22000.832', 15),
#  ('Windows SDK for Windows Store Apps DirectX x86 Remote', '10.1.22000.832', 15),
#  ('Windows SDK for Windows Store Apps Headers', '10.1.22000.832', 15),
#  ('Windows SDK for Windows Store Apps Libs', '10.1.22000.832', 15),
#  ('Windows SDK for Windows Store Apps Metadata', '10.1.22000.832', 15),
#  ('Windows SDK for Windows Store Apps Tools', '10.1.22000.832', 15),
#  ('Windows SDK for Windows Store Managed Apps Libs', '10.1.22000.832', 15),
#  ('Windows Subsystem for Linux', '2.0.9.0', 1),
#  ('Windows Subsystem for Linux Update', '5.10.16', 7),
#  ('Windows Subsystem for Linux WSLg Preview', '1.0.26', 4),
#  ('Windows Team Extension SDK', '10.1.22000.832', 15),
#  ('Windows Team Extension SDK Contracts', '10.1.22000.832', 15),
#  ('Windows Tools Versioned', '10.1.22621.382', 3),
#  ('Windows XP Targeting with C++', '11.0.51106', 2),
#  ('Xamarin Remoted iOS Simulator', '16.10.0.380', 4),
#  ('Zoom(64bit)', '5.12.10650', 1),
#  ('icecap_collection_neutral', '17.5.33312', 13),
#  ('icecap_collection_x64', '17.5.33306', 13),
#  ('icecap_collectionresources', '17.5.33312', 13),
#  ('icecap_collectionresourcesx64', '17.5.33306', 13),
#  ('vcpp_crt.redist.clickonce', '14.34.31938', 14),
#  ('vs_BlendMsi', '17.5.33306', 11),
#  ('vs_CoreEditorFonts', '17.5.33306', 11),
#  ('vs_FileTracker_Singleton', '17.5.33306', 13),
#  ('vs_Graphics_Singletonx64', '17.5.33312', 5),
#  ('vs_Graphics_Singletonx86', '17.5.33312', 5),
#  ('vs_SQLClickOnceBootstrappermsi', '17.5.33306', 12),
#  ('vs_clickoncebootstrappermsi', '17.5.33312', 12),
#  ('vs_clickoncebootstrappermsires', '17.5.33306', 12),
#  ('vs_clickoncesigntoolmsi', '17.5.33306', 12),
#  ('vs_communitymsi', '16.11.31911', 3),
#  ('vs_communitymsires', '17.5.33312', 13),
#  ('vs_communitysharedmsi', '17.5.33312', 11),
#  ('vs_communityx64msi', '17.5.33312', 11),
#  ('vs_devenvmsi', '16.0.28329', 2),
#  ('vs_devenvsharedmsi', '17.5.33306', 11),
#  ('vs_devenx64vmsi', '17.5.33306', 11),
#  ('vs_filehandler_amd64', '17.5.33310', 13),
#  ('vs_filehandler_x86', '17.5.33310', 13),
#  ('vs_githubprotocolhandlermsi', '17.8.34129', 1),
#  ('vs_minshellinteropmsi', '16.10.31306', 3),
#  ('vs_minshellinteropsharedmsi', '17.5.33306', 11),
#  ('vs_minshellinteropx64msi', '17.5.33306', 11),
#  ('vs_minshellmsi', '16.11.33130', 3),
#  ('vs_minshellmsires', '17.5.33306', 13),
#  ('vs_minshellsharedmsi', '17.5.33310', 11),
#  ('vs_minshellx64msi', '17.5.33306', 11),
#  ('vs_tipsmsi', '17.5.33306', 12),
#  ('vs_vswebprotocolselectormsi', '17.5.33306', 9),
#  ('windows_toolscorepkg', '17.5.33311', 9)]

# %%
query = '''
SELECT i.program_name, i.program_version, count(c.computer_name) AS number_of_computers
FROM installed_programs i
LEFT JOIN computers c ON i.computer_name = c.computer_name
GROUP BY program_name
HAVING i.program_name = (
    SELECT MAX(i.program_name) FROM installed_programs i2 WHERE i2.program_name = i.program_name
);
'''

df = pd.read_sql(query, conn)
df.head()
# Out:
#                           program_name program_version  number_of_computers
# 0          /Applications/Bitwarden.app        2023.1.1                    3
# 1            /Applications/Firefox.app         114.0.1                    2
# 2     /Applications/GitHub Desktop.app           3.3.3                    2
# 3      /Applications/Google Chrome.app  117.0.5938.149                    2
# 4  /Applications/JetBrains Toolbox.app    1.27.2.13801                    2

# %% [markdown]
# <font size='5'> 2c. Report each program and the ratio of which computers out of all computers have said programs installed. Express the ratio in the format of “**X** out of **Y**“ computers and as a percentage rounded to the 2nd. Hint: To calculate the percentage, you will have to cast one of the numbers to a decimal by multiplying them by **1.0**.</font>

# %%
# %%sql
#
# WITH total AS (SELECT COUNT(computer_name) AS total FROM computers)
# SELECT i.program_name, printf('%s out of %s computers', COUNT(DISTINCT i.computer_name), t.total) AS ratio, printf('%1.2f%%',ROUND((COUNT(DISTINCT i.computer_name) * 1.0 / t.total) *100, 2)) AS percent_computers_installed
# FROM computers c, total t
# RIGHT JOIN installed_programs i on c.computer_name = i.computer_name
# GROUP BY i.program_name;
# Out:
#  * sqlite:///cms.sqlite
# Done.
# [('/Applications/Bitwarden.app', '3 out of 38 computers', '7.89%'),
#  ('/Applications/Firefox.app', '2 out of 38 computers', '5.26%'),
#  ('/Applications/GitHub Desktop.app', '2 out of 38 computers', '5.26%'),
#  ('/Applications/Google Chrome.app', '2 out of 38 computers', '5.26%'),
#  ('/Applications/JetBrains Toolbox.app', '2 out of 38 computers', '5.26%'),
#  ('/Applications/Microsoft Outlook.app', '2 out of 38 computers', '5.26%'),
#  ('/Applications/Microsoft Teams.app', '2 out of 38 computers', '5.26%'),
#  ('/Applications/Obsidian.app', '2 out of 38 computers', '5.26%'),
#  ('/Applications/Postman.app', '2 out of 38 computers', '5.26%'),
#  ('/Applications/Safari.app', '2 out of 38 computers', '5.26%'),
#  ('/Applications/Splashtop Streamer.app', '1 out of 38 computers', '2.63%'),
#  ('/Applications/Visual Studio Code.app', '2 out of 38 computers', '5.26%'),
#  ('/Applications/Visual Studio.app', '2 out of 38 computers', '5.26%'),
#  ('/Applications/Xamarin Profiler.app', '2 out of 38 computers', '5.26%'),
#  ('/Applications/Xcode.app', '2 out of 38 computers', '5.26%'),
#  ('/Applications/zoom.us.app', '2 out of 38 computers', '5.26%'),
#  ('1password', '2 out of 38 computers', '5.26%'),
#  ('7-Zip 22.01 (x64 edition)', '1 out of 38 computers', '2.63%'),
#  ('AMD DVR64', '1 out of 38 computers', '2.63%'),
#  ('AMD Settings', '1 out of 38 computers', '2.63%'),
#  ('AMD WVR64', '1 out of 38 computers', '2.63%'),
#  ('API Monitor v2 (Alpha)', '1 out of 38 computers', '2.63%'),
#  ('AWS Command Line Interface v2', '4 out of 38 computers', '10.53%'),
#  ('Active Directory Authentication Library for SQL Server', '2 out of 38 computers', '5.26%'),
#  ('Adobe Acrobat (64-bit)', '3 out of 38 computers', '7.89%'),
#  ('Adobe Acrobat DC', '2 out of 38 computers', '5.26%'),
#  ('Adobe Acrobat DC (64-bit)', '3 out of 38 computers', '7.89%'),
#  ('Adobe Refresh Manager', '7 out of 38 computers', '18.42%'),
#  ('AdoptOpenJDK JRE with Hotspot 11.0.7.10 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Amazon Corretto (x64)', '1 out of 38 computers', '2.63%'),
#  ('Amazon Corretto 8 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Application Verifier x64 External Package', '8 out of 38 computers', '21.05%'),
#  ('Application Verifier x64 External Package (DesktopEditions)', '2 out of 38 computers', '5.26%'),
#  ('Application Verifier x64 External Package (OnecoreUAP)', '2 out of 38 computers', '5.26%'),
#  ('Bing Bar', '1 out of 38 computers', '2.63%'),
#  ('Bonjour', '1 out of 38 computers', '2.63%'),
#  ('Bonjour SDK', '1 out of 38 computers', '2.63%'),
#  ('Branding64', '1 out of 38 computers', '2.63%'),
#  ('Camtasia 2021', '1 out of 38 computers', '2.63%'),
#  ('DiagnosticsHub_CollectionService', '10 out of 38 computers', '26.32%'),
#  ('Documentation Manager', '2 out of 38 computers', '5.26%'),
#  ('Dolby Atmos Windows API SDK', '1 out of 38 computers', '2.63%'),
#  ('Dolby Atmos Windows APP', '1 out of 38 computers', '2.63%'),
#  ('Dynamic Application Loader Host Interface Service', '1 out of 38 computers', '2.63%'),
#  ('Eclipse Temurin JDK with Hotspot 17.0.5+8 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Eclipse Temurin JDK with Hotspot 17.0.7+7 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Eclipse Temurin JDK with Hotspot 8u372-b07 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Eclipse Temurin JRE with Hotspot 11.0.19+7 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Eclipse Temurin JRE with Hotspot 8u362-b09 (x86)', '2 out of 38 computers', '5.26%'),
#  ('Eclipse Temurin JRE with Hotspot 8u372-b07 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Elgato Camera Hub', '2 out of 38 computers', '5.26%'),
#  ('Elliptic Virtual Lock Sensor Service', '1 out of 38 computers', '2.63%'),
#  ('Enable UEFI SecureBoot Tool', '1 out of 38 computers', '2.63%'),
#  ('Entity Framework 6.2.0 Tools  for Visual Studio 2019', '2 out of 38 computers', '5.26%'),
#  ('Entity Framework 6.2.0 Tools  for Visual Studio 2022', '8 out of 38 computers', '21.05%'),
#  ('Git Extensions 4.2.1.17611', '1 out of 38 computers', '2.63%'),
#  ('GitHub CLI', '1 out of 38 computers', '2.63%'),
#  ('GitHub Desktop Deployment Tool', '1 out of 38 computers', '2.63%'),
#  ('GoTo Opener', '19 out of 38 computers', '50.00%'),
#  ('Google Chrome', '3 out of 38 computers', '7.89%'),
#  ('Google Update Helper', '1 out of 38 computers', '2.63%'),
#  ('HOTKEY', '6 out of 38 computers', '15.79%'),
#  ('HP Officejet 4620 series Basic Device Software', '1 out of 38 computers', '2.63%'),
#  ('HP Officejet 4620 series Help', '1 out of 38 computers', '2.63%'),
#  ('HP Officejet 4620 series Product Improvement Study', '1 out of 38 computers', '2.63%'),
#  ('HP Update', '1 out of 38 computers', '2.63%'),
#  ('IIS 10.0 Express', '10 out of 38 computers', '26.32%'),
#  ('Intel(R) Chipset Device Software', '1 out of 38 computers', '2.63%'),
#  ('Intel(R) Extreme Tuning Utility', '1 out of 38 computers', '2.63%'),
#  ('Intel(R) ME WMI Provider', '1 out of 38 computers', '2.63%'),
#  ('Intel(R) Management Engine Components', '2 out of 38 computers', '5.26%'),
#  ('Intel(R) Management Engine Driver', '2 out of 38 computers', '5.26%'),
#  ('Intel(R) Trusted Connect Service Client x64', '1 out of 38 computers', '2.63%'),
#  ('Intel(R) Trusted Connect Service Client x86', '1 out of 38 computers', '2.63%'),
#  ('Intel(R) Wireless Bluetooth(R)', '1 out of 38 computers', '2.63%'),
#  ('Intel® PROSet/Wireless WiFi Software', '1 out of 38 computers', '2.63%'),
#  ('Java(TM) SE Development Kit 19.0.1 (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('JetBrains ETW Host Service (x64)', '10 out of 38 computers', '26.32%'),
#  ('Kits Configuration Installer', '8 out of 38 computers', '21.05%'),
#  ('LibreOffice 7.5.2.2', '1 out of 38 computers', '2.63%'),
#  ('LibreOffice 7.5.3.2', '1 out of 38 computers', '2.63%'),
#  ('MSI Development Tools', '8 out of 38 computers', '21.05%'),
#  ('Microsoft Azure Authoring Tools - v2.9.7', '5 out of 38 computers', '13.16%'),
#  ('Microsoft Azure Compute Emulator - v2.9.7', '5 out of 38 computers', '13.16%'),
#  ('Microsoft Azure Information Protection', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Azure PowerShell - April 2018', '4 out of 38 computers', '10.53%'),
#  ('Microsoft Azure Storage Emulator - v5.10', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Build of OpenJDK with Hotspot 11.0.12+7 (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Build of OpenJDK with Hotspot 11.0.16.1+1 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Command Line Utilities 15 for SQL Server', '10 out of 38 computers', '26.32%'),
#  ('Microsoft HTML Help Workshop Package', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Intune Management Extension', '14 out of 38 computers', '36.84%'),
#  ('Microsoft Mouse and Keyboard Center', '1 out of 38 computers', '2.63%'),
#  ('Microsoft ODBC Driver 17 for SQL Server', '10 out of 38 computers', '26.32%'),
#  ('Microsoft S/MIME Control for Outlook on the web for Edge/Chrome', '1 out of 38 computers', '2.63%'),
#  ('Microsoft SQL Server 2016 LocalDB', '2 out of 38 computers', '5.26%'),
#  ('Microsoft SQL Server 2019 LocalDB', '9 out of 38 computers', '23.68%'),
#  ('Microsoft Silverlight', '1 out of 38 computers', '2.63%'),
#  ('Microsoft System CLR Types for SQL Server 2019', '9 out of 38 computers', '23.68%'),
#  ('Microsoft System CLR Types for SQL Server 2019 CTP2.2', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Teams', '22 out of 38 computers', '57.89%'),
#  ('Microsoft TestPlatform SDK Local Feed', '10 out of 38 computers', '26.32%'),
#  ('Microsoft UniversalWindowsPlatform SDK', '5 out of 38 computers', '13.16%'),
#  ('Microsoft Update Health Tools', '32 out of 38 computers', '84.21%'),
#  ('Microsoft VC++ redistributables repacked.', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2008 Redistributable - x64 9.0.30729.6161', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2008 Redistributable - x86 9.0.30729.6161', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2010  x64 Redistributable - 10.0.30319', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2010  x64 Redistributable - 10.0.40219', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Visual C++ 2010  x86 Redistributable - 10.0.30319', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2010  x86 Redistributable - 10.0.40219', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Visual C++ 2012 x64 Additional Runtime - 11.0.61030', '4 out of 38 computers', '10.53%'),
#  ('Microsoft Visual C++ 2012 x64 Minimum Runtime - 11.0.61030', '4 out of 38 computers', '10.53%'),
#  ('Microsoft Visual C++ 2012 x86 Additional Runtime - 11.0.61030', '4 out of 38 computers', '10.53%'),
#  ('Microsoft Visual C++ 2012 x86 Minimum Runtime - 11.0.61030', '4 out of 38 computers', '10.53%'),
#  ('Microsoft Visual C++ 2013 x64 Additional Runtime - 12.0.21005', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2013 x64 Additional Runtime - 12.0.40664', '5 out of 38 computers', '13.16%'),
#  ('Microsoft Visual C++ 2013 x64 Minimum Runtime - 12.0.21005', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2013 x64 Minimum Runtime - 12.0.40664', '5 out of 38 computers', '13.16%'),
#  ('Microsoft Visual C++ 2013 x86 Additional Runtime - 12.0.21005', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Visual C++ 2013 x86 Additional Runtime - 12.0.40664', '5 out of 38 computers', '13.16%'),
#  ('Microsoft Visual C++ 2013 x86 Minimum Runtime - 12.0.21005', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Visual C++ 2013 x86 Minimum Runtime - 12.0.40664', '5 out of 38 computers', '13.16%'),
#  ('Microsoft Visual C++ 2017 x64 Additional Runtime - 14.11.25325', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2017 x64 Minimum Runtime - 14.11.25325', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2019 X64 Additional Runtime - 14.26.28720', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2019 X64 Additional Runtime - 14.29.30037', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2019 X64 Debug Runtime - 14.29.30139', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2019 X64 Minimum Runtime - 14.26.28720', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2019 X64 Minimum Runtime - 14.29.30037', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2019 X86 Additional Runtime - 14.23.27820', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2019 X86 Additional Runtime - 14.29.30037', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2019 X86 Debug Runtime - 14.29.30139', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2019 X86 Minimum Runtime - 14.23.27820', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2019 X86 Minimum Runtime - 14.29.30037', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2022 X64 Additional Runtime - 14.30.30704', '5 out of 38 computers', '13.16%'),
#  ('Microsoft Visual C++ 2022 X64 Additional Runtime - 14.32.31326', '4 out of 38 computers', '10.53%'),
#  ('Microsoft Visual C++ 2022 X64 Additional Runtime - 14.32.31332', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2022 X64 Additional Runtime - 14.34.31931', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2022 X64 Additional Runtime - 14.34.31938', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Visual C++ 2022 X64 Additional Runtime - 14.36.32532', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Visual C++ 2022 X64 Additional Runtime - 14.38.33130', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2022 X64 Debug Runtime - 14.34.31931', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2022 X64 Debug Runtime - 14.34.31938', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.30.30704', '5 out of 38 computers', '13.16%'),
#  ('Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.32.31326', '4 out of 38 computers', '10.53%'),
#  ('Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.32.31332', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.34.31931', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.34.31938', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.36.32532', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Visual C++ 2022 X64 Minimum Runtime - 14.38.33130', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2022 X86 Additional Runtime - 14.30.30704', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2022 X86 Additional Runtime - 14.32.31326', '4 out of 38 computers', '10.53%'),
#  ('Microsoft Visual C++ 2022 X86 Additional Runtime - 14.34.31931', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Visual C++ 2022 X86 Additional Runtime - 14.34.31938', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Visual C++ 2022 X86 Additional Runtime - 14.36.32532', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2022 X86 Additional Runtime - 14.38.33130', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2022 X86 Debug Runtime - 14.34.31931', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2022 X86 Debug Runtime - 14.34.31938', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Visual C++ 2022 X86 Minimum Runtime - 14.30.30704', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual C++ 2022 X86 Minimum Runtime - 14.32.31326', '4 out of 38 computers', '10.53%'),
#  ('Microsoft Visual C++ 2022 X86 Minimum Runtime - 14.34.31931', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Visual C++ 2022 X86 Minimum Runtime - 14.34.31938', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Visual C++ 2022 X86 Minimum Runtime - 14.36.32532', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Visual C++ 2022 X86 Minimum Runtime - 14.38.33130', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual Studio 2010 Tools for Office Runtime (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Visual Studio Setup Configuration', '11 out of 38 computers', '28.95%'),
#  ('Microsoft Visual Studio Setup WMI Provider', '11 out of 38 computers', '28.95%'),
#  ('Microsoft Web Deploy 4.0', '9 out of 38 computers', '23.68%'),
#  ('Microsoft Windows Desktop Runtime - 3.1.31 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 3.1.31 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 3.1.32 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 5.0.17 (x64)', '5 out of 38 computers', '13.16%'),
#  ('Microsoft Windows Desktop Runtime - 5.0.17 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.1 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.1 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.10 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.10 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.11 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.11 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.13 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.13 (x86)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.15 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.15 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.16 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.16 (x86)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.18 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.18 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.22 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.25 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.25 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 6.0.9 (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Windows Desktop Runtime - 7.0.0 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 7.0.11 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 7.0.2 (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Windows Desktop Runtime - 7.0.2 (x86)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Runtime - 7.0.4 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Runtime - 7.0.4 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 7.0.5 (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Windows Desktop Runtime - 7.0.5 (x86)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Runtime - 7.0.7 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 7.0.7 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 8.0.0 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 8.0.0 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Runtime - 8.0.0 Preview 3 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 3.1.0 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 5.0.0 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.0 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.10 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.10 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.11 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.13 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.13 (x86)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.15 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.15 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.16 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.16 (x86)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.18 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.18 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.22 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.25 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.25 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 6.0.9 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.11 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.2 (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.2 (x86)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.4 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.4 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.5 (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.5 (x86)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.7 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 7.0.7 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 8.0.0 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 8.0.0 (x86)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft Windows Desktop Targeting Pack - 8.0.0 Preview 3 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft.Android.Ref.31 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft.Android.Ref.33 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft.Android.Runtime.31.android-arm (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft.Android.Runtime.31.android-arm64 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft.Android.Runtime.31.android-x64 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft.Android.Runtime.31.android-x86 (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft.Android.Runtime.33.android-arm (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft.Android.Runtime.33.android-arm64 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft.Android.Runtime.33.android-x64 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft.Android.Runtime.33.android-x86 (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft.Android.Sdk.Windows (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.MacCatalyst.Ref (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.MacCatalyst.Runtime.maccatalyst-arm64 (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.MacCatalyst.Runtime.maccatalyst-x64 (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.MacCatalyst.Sdk (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.MacCatalyst.Templates (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Controls.Ref.android (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Controls.Ref.any (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Controls.Ref.ios (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Controls.Ref.maccatalyst (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Controls.Ref.win (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Controls.Runtime.android (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Controls.Runtime.any (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Controls.Runtime.ios (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Controls.Runtime.maccatalyst (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Controls.Runtime.win (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Core.Ref.android (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Core.Ref.any (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Core.Ref.ios (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Core.Ref.maccatalyst (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Core.Ref.win (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Core.Runtime.android (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Core.Runtime.any (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Core.Runtime.ios (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Core.Runtime.maccatalyst (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Core.Runtime.win (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Dependencies (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft.Maui.Essentials.Ref.android (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Essentials.Ref.any (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Essentials.Ref.ios (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Essentials.Ref.maccatalyst (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Essentials.Ref.win (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Essentials.Runtime.android (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Essentials.Runtime.any (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Essentials.Runtime.ios (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Essentials.Runtime.maccatalyst (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Essentials.Runtime.win (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Extensions (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft.Maui.Graphics (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Graphics.Win2D.WinUI (x64)', '1 out of 38 computers', '2.63%'),
#  ('Microsoft.Maui.Graphics.Win2D.WinUI.Desktop (x64)', '2 out of 38 computers', '5.26%'),
#  ('Microsoft.Maui.Resizetizer.Sdk (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.Maui.Sdk (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.iOS.Ref (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.iOS.Runtime.ios-arm (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.iOS.Runtime.ios-arm64 (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.iOS.Runtime.iossimulator-arm64 (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.iOS.Runtime.iossimulator-x64 (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.iOS.Runtime.iossimulator-x86 (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.iOS.Sdk (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.iOS.Templates (x64)', '3 out of 38 computers', '7.89%'),
#  ('Microsoft.iOS.Windows.Sdk (x64)', '3 out of 38 computers', '7.89%'),
#  ('Minimal WLPC Content', '1 out of 38 computers', '2.63%'),
#  ('Network Monitor Parsers', '1 out of 38 computers', '2.63%'),
#  ('OA3Tool', '1 out of 38 computers', '2.63%'),
#  ('OEM Test Certificates (OnecoreUAP)', '1 out of 38 computers', '2.63%'),
#  ('Office 16 Click-to-Run Extensibility Component', '24 out of 38 computers', '63.16%'),
#  ('Office 16 Click-to-Run Extensibility Component 64-bit Registration', '1 out of 38 computers', '2.63%'),
#  ('Office 16 Click-to-Run Licensing Component', '24 out of 38 computers', '63.16%'),
#  ('Office 16 Click-to-Run Localization Component', '4 out of 38 computers', '10.53%'),
#  ('OneCoreUap_ApiValidator_WDK_Kit_Content', '1 out of 38 computers', '2.63%'),
#  ('OneCoreUap_WDTF_Headers_and_Libs_Kit_Content', '1 out of 38 computers', '2.63%'),
#  ('OpenSSH', '1 out of 38 computers', '2.63%'),
#  ('Oracle VM VirtualBox 7.0.12', '1 out of 38 computers', '2.63%'),
#  ('Oracle VM VirtualBox 7.0.6', '1 out of 38 computers', '2.63%'),
#  ('Oracle VM VirtualBox 7.0.8', '1 out of 38 computers', '2.63%'),
#  ('PDF Suite 2020', '1 out of 38 computers', '2.63%'),
#  ('PDF Suite 2020 OCR TESS Module', '1 out of 38 computers', '2.63%'),
#  ('PowerShell 7-x64', '4 out of 38 computers', '10.53%'),
#  ('PowerToys (Preview)', '1 out of 38 computers', '2.63%'),
#  ('PuTTY release 0.75 (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('PuTTY release 0.76 (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('PuTTY release 0.78 (64-bit)', '3 out of 38 computers', '7.89%'),
#  ('Puppet (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 2.7.13 (64-bit)', '2 out of 38 computers', '5.26%'),
#  ('Python 3.10.8 Add to Path (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.10.8 Core Interpreter (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.10.8 Development Libraries (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.10.8 Documentation (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.10.8 Executables (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.10.8 Standard Library (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.10.8 Tcl/Tk Support (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.10.8 Test Suite (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.10.8 Utility Scripts (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.10.8 pip Bootstrap (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.0 Add to Path (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.0 Core Interpreter (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.0 Development Libraries (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.0 Documentation (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.0 Executables (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.0 Standard Library (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.0 Tcl/Tk Support (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.0 Test Suite (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.0 Utility Scripts (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.0 pip Bootstrap (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.3 Add to Path (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.3 Core Interpreter (32-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.3 Core Interpreter (64-bit)', '3 out of 38 computers', '7.89%'),
#  ('Python 3.11.3 Development Libraries (32-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.3 Development Libraries (64-bit)', '3 out of 38 computers', '7.89%'),
#  ('Python 3.11.3 Documentation (32-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.3 Documentation (64-bit)', '3 out of 38 computers', '7.89%'),
#  ('Python 3.11.3 Executables (32-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.3 Executables (64-bit)', '3 out of 38 computers', '7.89%'),
#  ('Python 3.11.3 Standard Library (32-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.3 Standard Library (64-bit)', '3 out of 38 computers', '7.89%'),
#  ('Python 3.11.3 Tcl/Tk Support (32-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.3 Tcl/Tk Support (64-bit)', '3 out of 38 computers', '7.89%'),
#  ('Python 3.11.3 Test Suite (32-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.3 Test Suite (64-bit)', '3 out of 38 computers', '7.89%'),
#  ('Python 3.11.3 Utility Scripts (32-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.3 Utility Scripts (64-bit)', '3 out of 38 computers', '7.89%'),
#  ('Python 3.11.3 pip Bootstrap (32-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.3 pip Bootstrap (64-bit)', '3 out of 38 computers', '7.89%'),
#  ('Python 3.11.4 Core Interpreter (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.4 Development Libraries (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.4 Documentation (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.4 Executables (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.4 Standard Library (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.4 Tcl/Tk Support (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.4 Test Suite (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.4 Utility Scripts (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.11.4 pip Bootstrap (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.9.7 Core Interpreter (64-bit symbols)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.9.7 Core Interpreter (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.9.7 Development Libraries (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.9.7 Documentation (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.9.7 Executables (64-bit symbols)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.9.7 Executables (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.9.7 Standard Library (64-bit symbols)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.9.7 Standard Library (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.9.7 Tcl/Tk Support (64-bit symbols)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.9.7 Tcl/Tk Support (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.9.7 Test Suite (64-bit symbols)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.9.7 Test Suite (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.9.7 Utility Scripts (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python 3.9.7 pip Bootstrap (64-bit)', '1 out of 38 computers', '2.63%'),
#  ('Python Launcher', '7 out of 38 computers', '18.42%'),
#  ('QEMU guest agent', '4 out of 38 computers', '10.53%'),
#  ('Quickpass', '10 out of 38 computers', '26.32%'),
#  ('Red Hat QXL controller', '2 out of 38 computers', '5.26%'),
#  ('SDK ARM Additions', '8 out of 38 computers', '21.05%'),
#  ('SDK ARM Additions EULA', '1 out of 38 computers', '2.63%'),
#  ('SDK ARM Redistributables', '8 out of 38 computers', '21.05%'),
#  ('SDK Debuggers ARM', '1 out of 38 computers', '2.63%'),
#  ('SRA-Tool', '1 out of 38 computers', '2.63%'),
#  ('Sophos AutoUpdate XG', '1 out of 38 computers', '2.63%'),
#  ('Sophos Endpoint Agent', '1 out of 38 computers', '2.63%'),
#  ('Sophos Home', '1 out of 38 computers', '2.63%'),
#  ('Spice Agent 0.10.0-5 (64-bit)', '2 out of 38 computers', '5.26%'),
#  ('Splashtop Streamer', '13 out of 38 computers', '34.21%'),
#  ('Splashtop for RMM', '1 out of 38 computers', '2.63%'),
#  ('Thunderbolt™ Software', '1 out of 38 computers', '2.63%'),
#  ('TypeScript SDK', '2 out of 38 computers', '5.26%'),
#  ('Universal CRT Extension SDK', '8 out of 38 computers', '21.05%'),
#  ('Universal CRT Headers Libraries and Sources', '8 out of 38 computers', '21.05%'),
#  ('Universal CRT Redistributable', '8 out of 38 computers', '21.05%'),
#  ('Universal CRT Tools x64', '8 out of 38 computers', '21.05%'),
#  ('Universal CRT Tools x86', '8 out of 38 computers', '21.05%'),
#  ('Universal General MIDI DLS Extension SDK', '8 out of 38 computers', '21.05%'),
#  ('Update for Windows 10 for x64-based Systems (KB5001716)', '2 out of 38 computers', '5.26%'),
#  ('VMware Player', '1 out of 38 computers', '2.63%'),
#  ('VMware Tools', '1 out of 38 computers', '2.63%'),
#  ('VMware Workstation', '3 out of 38 computers', '7.89%'),
#  ('VS Immersive Activate Helper', '10 out of 38 computers', '26.32%'),
#  ('VS JIT Debugger', '9 out of 38 computers', '23.68%'),
#  ('VS Script Debugging Common', '11 out of 38 computers', '28.95%'),
#  ('VeraCrypt 1.25.9', '3 out of 38 computers', '7.89%'),
#  ('Virtio-win-driver-installer', '2 out of 38 computers', '5.26%'),
#  ('Visual C++ CRT Headers Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium ARM Base Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium ARM Base Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X64 ARM Cross Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X64 ARM Cross Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X64 Base Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X64 Base Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X64 Native Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X64 Native Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X64 X86 Cross Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X64 X86 Cross Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X86 ARM Cross Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X86 ARM Cross Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X86 Base Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X86 Base Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X86 Native Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X86 Native Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X86 X64 Cross Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools Premium X86 X64 Cross Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X64 ARM Cross Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X64 ARM Cross Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X64 Base Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X64 Base Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X64 Native Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X64 Native Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X64 X86 Cross Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X64 X86 Cross Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X86 ARM Cross Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X86 ARM Cross Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X86 Base Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X86 Base Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X86 Native Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X86 Native Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X86 X64 Cross Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Compiler/Tools X86 X64 Cross Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Extra Files', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Extra Resource Files', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library ATL ARM Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library ATL Headers Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library ATL Source Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library ATL X64 Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library ATL X86 Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library CRT ARM Desktop Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library CRT ARM OneCore For Desktop Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library CRT ARM Redist Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library CRT ARM Store Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library CRT ARM64 Appx Package', '7 out of 38 computers', '18.42%'),
#  ('Visual C++ Library CRT Appx Package', '7 out of 38 computers', '18.42%'),
#  ('Visual C++ Library CRT Appx Resource Package', '7 out of 38 computers', '18.42%'),
#  ('Visual C++ Library CRT Desktop Appx Package', '7 out of 38 computers', '18.42%'),
#  ('Visual C++ Library CRT Redist Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library CRT Source Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library CRT X64 Desktop Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library CRT X64 OneCore For Desktop Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library CRT X64 Redist Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library CRT X64 Store Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library CRT X86 Desktop Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library CRT X86 OneCore For Desktop Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library CRT X86 Redist Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library CRT X86 Store Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library MFC Headers Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library MFC MBCS Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library MFC Source Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library MFC X64 Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library MFC X86 Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library PGO ARM Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library PGO Headers Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library PGO X64 Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ Library PGO X86 Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ MSBuild ARM Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ MSBuild Base Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ MSBuild Base Resource Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ MSBuild X64 Package', '1 out of 38 computers', '2.63%'),
#  ('Visual C++ MSBuild X86 Package', '1 out of 38 computers', '2.63%'),
#  ('WD Drive Utilities', '1 out of 38 computers', '2.63%'),
#  ('WinAppDeploy', '8 out of 38 computers', '21.05%'),
#  ('WinRT Intellisense Desktop - Other Languages', '8 out of 38 computers', '21.05%'),
#  ('WinRT Intellisense Desktop - en-us', '8 out of 38 computers', '21.05%'),
#  ('WinRT Intellisense IoT - Other Languages', '8 out of 38 computers', '21.05%'),
#  ('WinRT Intellisense IoT - en-us', '8 out of 38 computers', '21.05%'),
#  ('WinRT Intellisense Mobile - en-us', '8 out of 38 computers', '21.05%'),
#  ('WinRT Intellisense PPI - Other Languages', '8 out of 38 computers', '21.05%'),
#  ('WinRT Intellisense PPI - en-us', '8 out of 38 computers', '21.05%'),
#  ('WinRT Intellisense UAP - Other Languages', '8 out of 38 computers', '21.05%'),
#  ('WinRT Intellisense UAP - en-us', '8 out of 38 computers', '21.05%'),
#  ('Windows App Certification Kit Native Components', '8 out of 38 computers', '21.05%'),
#  ('Windows App Certification Kit SupportedApiList x86', '8 out of 38 computers', '21.05%'),
#  ('Windows App Certification Kit x64', '8 out of 38 computers', '21.05%'),
#  ('Windows App Certification Kit x64 (OnecoreUAP)', '2 out of 38 computers', '5.26%'),
#  ('Windows Content Versioned', '1 out of 38 computers', '2.63%'),
#  ('Windows Debugging WDK Integration Versioned', '1 out of 38 computers', '2.63%'),
#  ('Windows Deployment Image Servicing and Management Tools (OnecoreUAP)', '1 out of 38 computers', '2.63%'),
#  ('Windows Desktop Extension SDK', '8 out of 38 computers', '21.05%'),
#  ('Windows Desktop Extension SDK Contracts', '8 out of 38 computers', '21.05%'),
#  ('Windows Driver Framework ARM Headers and Libs', '1 out of 38 computers', '2.63%'),
#  ('Windows Driver Framework Headers and Libs', '1 out of 38 computers', '2.63%'),
#  ('Windows Driver Kit', '1 out of 38 computers', '2.63%'),
#  ('Windows Driver Kit ARM Additions', '1 out of 38 computers', '2.63%'),
#  ('Windows Driver Kit ARM Binaries', '1 out of 38 computers', '2.63%'),
#  ('Windows Driver Kit ARM Headers and Libs', '1 out of 38 computers', '2.63%'),
#  ('Windows Driver Kit Binaries', '1 out of 38 computers', '2.63%'),
#  ('Windows Driver Kit Downlevel Dev14 Content', '1 out of 38 computers', '2.63%'),
#  ('Windows Driver Kit Headers and Libs', '1 out of 38 computers', '2.63%'),
#  ('Windows Driver Kit Logger', '1 out of 38 computers', '2.63%'),
#  ('Windows Driver Kit Root Dev17 Content', '1 out of 38 computers', '2.63%'),
#  ('Windows Driver Kit SxS Content', '1 out of 38 computers', '2.63%'),
#  ('Windows Driver Kit Visual Studio Dev17 Content', '1 out of 38 computers', '2.63%'),
#  ('Windows Espc Package', '1 out of 38 computers', '2.63%'),
#  ('Windows IoT Extension SDK', '8 out of 38 computers', '21.05%'),
#  ('Windows IoT Extension SDK Contracts', '8 out of 38 computers', '21.05%'),
#  ('Windows Mobile Extension SDK', '8 out of 38 computers', '21.05%'),
#  ('Windows Mobile Extension SDK Contracts', '8 out of 38 computers', '21.05%'),
#  ('Windows OEM Preproduction Desktop Policies)', '1 out of 38 computers', '2.63%'),
#  ('Windows PC Health Check', '3 out of 38 computers', '7.89%'),
#  ('Windows Phone SDK 8.0 Assemblies for Visual Studio 2019', '2 out of 38 computers', '5.26%'),
#  ('Windows SDK', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK ARM Desktop Tools', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK ARM Headers Libs Metadata', '1 out of 38 computers', '2.63%'),
#  ('Windows SDK AddOn', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Desktop Headers arm', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Desktop Headers arm64', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Desktop Headers x64', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Desktop Headers x86', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Desktop Libs arm', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Desktop Libs arm64', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Desktop Libs x64', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Desktop Libs x86', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Desktop Tools arm64', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Desktop Tools x64', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Desktop Tools x86', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK DirectX x64 Remote', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK DirectX x86 Remote', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK EULA', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Facade Windows WinMD Versioned', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Modern Non-Versioned Developer Tools', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Modern Versioned Developer Tools', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Redistributables', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK Signing Tools', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK for Windows Store Apps', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK for Windows Store Apps Contracts', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK for Windows Store Apps DirectX x86 Remote', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK for Windows Store Apps Headers', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK for Windows Store Apps Libs', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK for Windows Store Apps Metadata', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK for Windows Store Apps Tools', '8 out of 38 computers', '21.05%'),
#  ('Windows SDK for Windows Store Managed Apps Libs', '8 out of 38 computers', '21.05%'),
#  ('Windows Subsystem for Linux', '1 out of 38 computers', '2.63%'),
#  ('Windows Subsystem for Linux Update', '7 out of 38 computers', '18.42%'),
#  ('Windows Subsystem for Linux WSLg Preview', '4 out of 38 computers', '10.53%'),
#  ('Windows Team Extension SDK', '8 out of 38 computers', '21.05%'),
#  ('Windows Team Extension SDK Contracts', '8 out of 38 computers', '21.05%'),
#  ('Windows Tools Versioned', '1 out of 38 computers', '2.63%'),
#  ('Windows XP Targeting with C++', '1 out of 38 computers', '2.63%'),
#  ('Xamarin Remoted iOS Simulator', '4 out of 38 computers', '10.53%'),
#  ('Zoom(64bit)', '1 out of 38 computers', '2.63%'),
#  ('icecap_collection_neutral', '10 out of 38 computers', '26.32%'),
#  ('icecap_collection_x64', '10 out of 38 computers', '26.32%'),
#  ('icecap_collectionresources', '10 out of 38 computers', '26.32%'),
#  ('icecap_collectionresourcesx64', '10 out of 38 computers', '26.32%'),
#  ('vcpp_crt.redist.clickonce', '11 out of 38 computers', '28.95%'),
#  ('vs_BlendMsi', '9 out of 38 computers', '23.68%'),
#  ('vs_CoreEditorFonts', '9 out of 38 computers', '23.68%'),
#  ('vs_FileTracker_Singleton', '11 out of 38 computers', '28.95%'),
#  ('vs_Graphics_Singletonx64', '3 out of 38 computers', '7.89%'),
#  ('vs_Graphics_Singletonx86', '3 out of 38 computers', '7.89%'),
#  ('vs_SQLClickOnceBootstrappermsi', '10 out of 38 computers', '26.32%'),
#  ('vs_clickoncebootstrappermsi', '10 out of 38 computers', '26.32%'),
#  ('vs_clickoncebootstrappermsires', '10 out of 38 computers', '26.32%'),
#  ('vs_clickoncesigntoolmsi', '10 out of 38 computers', '26.32%'),
#  ('vs_communitymsi', '3 out of 38 computers', '7.89%'),
#  ('vs_communitymsires', '11 out of 38 computers', '28.95%'),
#  ('vs_communitysharedmsi', '9 out of 38 computers', '23.68%'),
#  ('vs_communityx64msi', '9 out of 38 computers', '23.68%'),
#  ('vs_devenvmsi', '2 out of 38 computers', '5.26%'),
#  ('vs_devenvsharedmsi', '9 out of 38 computers', '23.68%'),
#  ('vs_devenx64vmsi', '9 out of 38 computers', '23.68%'),
#  ('vs_filehandler_amd64', '11 out of 38 computers', '28.95%'),
#  ('vs_filehandler_x86', '11 out of 38 computers', '28.95%'),
#  ('vs_githubprotocolhandlermsi', '1 out of 38 computers', '2.63%'),
#  ('vs_minshellinteropmsi', '3 out of 38 computers', '7.89%'),
#  ('vs_minshellinteropsharedmsi', '9 out of 38 computers', '23.68%'),
#  ('vs_minshellinteropx64msi', '9 out of 38 computers', '23.68%'),
#  ('vs_minshellmsi', '3 out of 38 computers', '7.89%'),
#  ('vs_minshellmsires', '11 out of 38 computers', '28.95%'),
#  ('vs_minshellsharedmsi', '9 out of 38 computers', '23.68%'),
#  ('vs_minshellx64msi', '9 out of 38 computers', '23.68%'),
#  ('vs_tipsmsi', '10 out of 38 computers', '26.32%'),
#  ('vs_vswebprotocolselectormsi', '7 out of 38 computers', '18.42%'),
#  ('windows_toolscorepkg', '7 out of 38 computers', '18.42%')]

# %%
query = '''
WITH total AS (SELECT COUNT(computer_name) AS total FROM computers)
SELECT i.program_name, printf('%s out of %s computers', COUNT(DISTINCT i.computer_name), t.total) AS ratio, printf('%1.2f%%',ROUND((COUNT(DISTINCT i.computer_name) * 1.0 / t.total) *100, 2)) AS percent_computers_installed
FROM computers c, total t
RIGHT JOIN installed_programs i on c.computer_name = i.computer_name
GROUP BY i.program_name;
'''

df = pd.read_sql(query, conn)
df.head()
# Out:
#                           program_name                  ratio  \
# 0          /Applications/Bitwarden.app  3 out of 38 computers
# 1            /Applications/Firefox.app  2 out of 38 computers
# 2     /Applications/GitHub Desktop.app  2 out of 38 computers
# 3      /Applications/Google Chrome.app  2 out of 38 computers
# 4  /Applications/JetBrains Toolbox.app  2 out of 38 computers
#
#   percent_computers_installed
# 0                       7.89%
# 1                       5.26%
# 2                       5.26%
# 3                       5.26%
# 4                       5.26%

# %% [markdown]
# <font size='5'>3a. Report which admin computers have logins on or later than May 2023, have **Python** installed on their computers and whose IP addresses are not in the IP whitelist table. Be sure to include the computer name, IP address and login timestamp; order the results by most recent date and computer name.</font>

# %%
# %%sql
#
# SELECT c.computer_name, l.login_ip,
# STRFTIME('%Y-%m-%d %H:%M:%S', l.login_timestamp) AS formatted_login_timestamp
# FROM computers c
# INNER JOIN installed_programs i ON c.computer_name = i.computer_name
# INNER JOIN login_records l ON c.computer_name = l.computer_name
# LEFT  JOIN ip_whitelist ip on l.login_ip = ip.login_ip
# WHERE (
#     c.computer_type LIKE 'Admin'
#     AND ip.login_ip IS null
#     AND i.program_name LIKE '%Python%'
#     AND formatted_login_timestamp >= date('2023-05-01 00:00:00')
# )
# ORDER BY formatted_login_timestamp DESC,
#          c.computer_name ASC;
# Out:
#  * sqlite:///cms.sqlite
# Done.
# [('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:48'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:48'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:48'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:48'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:48'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:48'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:48'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:48'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:48'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:48'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:45'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:45'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:45'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:45'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:45'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:45'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:45'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:45'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:45'),
#  ('PLAINCORP-13', '73.18.119.169', '2023-07-19 15:56:45'),
#  ('DESKTOP-AFKOOLQ', '75.19.119.2', '2023-06-20 15:00:10'),
#  ('DESKTOP-AFKOOLQ', '75.19.119.2', '2023-06-20 15:00:10'),
#  ('DESKTOP-AFKOOLQ', '75.19.119.2', '2023-06-20 15:00:10'),
#  ('DESKTOP-AFKOOLQ', '75.19.119.2', '2023-06-20 15:00:10'),
#  ('DESKTOP-AFKOOLQ', '75.19.119.2', '2023-06-20 15:00:10'),
#  ('DESKTOP-AFKOOLQ', '75.19.119.2', '2023-06-20 15:00:10'),
#  ('DESKTOP-AFKOOLQ', '75.19.119.2', '2023-06-20 15:00:10'),
#  ('DESKTOP-AFKOOLQ', '75.19.119.2', '2023-06-20 15:00:10'),
#  ('DESKTOP-AFKOOLQ', '75.19.119.2', '2023-06-20 15:00:10'),
#  ('DESKTOP-AFKOOLQ', '75.19.119.2', '2023-06-20 15:00:10'),
#  ('DESKTOP-AFKOOLQ', '75.19.119.2', '2023-06-20 15:00:10')]

# %% [markdown]
# <font size='5'>3b. Below are the requirements for the modifications you should make to the PD output from **3a**, you cannot change the SQL query to meet these requirements:</font>
# - <font size='5'>Replace the 2nd and 4th octets of the IP address with **\*** (e.g., 10.\*.0.\*). Your solution must use regex.</font>
# - <font size='5'>Format the login timestamp as the date only (e.g., 01/20/2024)</font>

# %%
query = '''
SELECT c.computer_name, l.login_ip, 
STRFTIME('%Y-%m-%d %H:%M:%S', l.login_timestamp) AS formatted_login_timestamp
FROM computers c
INNER JOIN installed_programs i ON c.computer_name = i.computer_name
INNER JOIN login_records l ON c.computer_name = l.computer_name
LEFT  JOIN ip_whitelist ip on l.login_ip = ip.login_ip
WHERE (
    c.computer_type LIKE 'Admin'
    AND ip.login_ip IS null
    AND i.program_name LIKE '%Python%'
    AND formatted_login_timestamp >= date('2023-05-01 00:00:00')
)
ORDER BY formatted_login_timestamp DESC, 
         c.computer_name ASC;
'''
df = pd.read_sql(query, conn)
df['formatted_login_timestamp'] = df['formatted_login_timestamp'].str.slice(stop = 10)
df['formatted_login_timestamp'] = df['formatted_login_timestamp'].str.replace('-', '/')
df['login_ip'] = df['login_ip'].str.replace('(\d*\.)(\d*)(\.\d*\.)(\d*)', '\\1*\\3*', regex = True)
df.head()
# Out:
#   computer_name    login_ip formatted_login_timestamp
# 0  PLAINCORP-13  73.*.119.*                2023/07/19
# 1  PLAINCORP-13  73.*.119.*                2023/07/19
# 2  PLAINCORP-13  73.*.119.*                2023/07/19
# 3  PLAINCORP-13  73.*.119.*                2023/07/19
# 4  PLAINCORP-13  73.*.119.*                2023/07/19

# %% [markdown]
# <font size='5'>4. Bob from the IT department noticed a SQL query was starting to get slow and since he knew a little bit of SQL from college, he decided to fix the query himself. The first thing Bob did was to reduce the number of unnecessary joins in the query, but the new query was still slow. Was Bob’s initial approach the correct one? If so, explain Bob's next steps? If not, explain what Bob should've done instead?</font>

# %% [markdown]
# - Bob's initial approach to speeding the SQL query was a fine place to start. Unneccessary joins (especially unintentional Cartesian Joins) can certainly slow down a query, but care must be taken to ensure that such changes don't negatively impact the query results. Bob's first step should be to ensure the success of each query where he altered the present joins.
# - Next, Bob would do well to ensure the implementation of a high-performance indexing pattern. Indexes provide a method to locate data more quickly, and avoid searching over an entire table for the desired entry. This may improve the performance of the query, depending on the exact type of operations being performed within.
# - Bob could also ensure that the SELECT statement was tailored for the exact query and did not return unnecessary data with a generic all (*) call. Further, Bob would do well to minimize the use of subqueries in favor of CTEs, as these are generally better-performing.
# - If Bob was still unsatisfied with the performance of his query, he has more options still:
#     1. Bob could consider altering the database, itself, inasmuch as denormalization could increase query performance.
#     2. Depending on Bob's level of expertise and platform, he may also be well-served by accessing the SQL optimizer in order to ascertain which operations are the most costly and refine the SQL queries further with this information in mind.

# %% [markdown]
# <font size='5'>5. To improve the CMS’s backend and report capabilities, the IT department wants to provide feedback to the contractor who built the CMS solution and wants your input.  How would you improve or change the data model? If you decide to create a data diagram you must save it as a PDF file in the same folder as this Jupyter Notebook.</font>

# %% [markdown]
# - A primary note would be to scrub the data input to the installed_programs table, such that there is no redundancy in the version number. As this table stands now, the version number is included twice in some entries both in the version number column and alongside the program's name which makes application version tracking difficult.
# - As discovered in the EDA below, the CMS has an issue with the handling of macOS systems which would need to be rectified for correct date reporting and verified for total success on these systems.
# - The use of 'computer name' as the primary key for computers and foreign key for all other tables except ip_whitelist is clunky, and ought to be replaced by a more streamlined computer_id which is unique, non-null, and auto-incremented. This would prevent some issues in querying where system names are similar.

# %% [markdown]
# <font size='5'>6. Did you notice anything interesting or anything wrong with the data? If so, please describe what you found and if possible, provide any related evidence.</font>

# %% [markdown]
# - An initial finding was that it was somewhat strange that some computers had no listed last full scan date, but still had listed programs under them. With the execution of the below query, it was also noted that every computer with this quirk was running macOS.

# %%
# %%sql
#
# SELECT * FROM computers c
# INNER JOIN installed_programs i ON c.computer_name = i.computer_name
# WHERE c.last_full_scan_date IS NULL
# Out:
#  * sqlite:///cms.sqlite
# Done.
# [('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2113, 'Testers-Mac-mini', '/Applications/Bitwarden.app', '2023.1.1'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2114, 'Testers-Mac-mini', '/Applications/Firefox.app', '114.0.1'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2115, 'Testers-Mac-mini', '/Applications/GitHub Desktop.app', '3.3.3'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2116, 'Testers-Mac-mini', '/Applications/Google Chrome.app', '117.0.5938.149'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2117, 'Testers-Mac-mini', '/Applications/JetBrains Toolbox.app', '1.27.2.13801'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2118, 'Testers-Mac-mini', '/Applications/Microsoft Outlook.app', '16.69.1'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2119, 'Testers-Mac-mini', '/Applications/Microsoft Teams.app', '1.00.624065'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2120, 'Testers-Mac-mini', '/Applications/Obsidian.app', '1.1.9'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2121, 'Testers-Mac-mini', '/Applications/Postman.app', '10.13.0'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2122, 'Testers-Mac-mini', '/Applications/Safari.app', '17.0'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2123, 'Testers-Mac-mini', '/Applications/Splashtop Streamer.app', '3.5.8.1'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2124, 'Testers-Mac-mini', '/Applications/Visual Studio Code.app', '1.82.2'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2125, 'Testers-Mac-mini', '/Applications/Visual Studio.app', '17.4.3.21'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2126, 'Testers-Mac-mini', '/Applications/Xamarin Profiler.app', '1.8.0.19'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2127, 'Testers-Mac-mini', '/Applications/Xcode.app', '14.2'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2128, 'Testers-Mac-mini', '/Applications/zoom.us.app', '5.13.7 (15481)'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2129, 'Testers-Mini', '/Applications/Bitwarden.app', '2023.1.1'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2130, 'Testers-Mini', '/Applications/Firefox.app', '111.0.1'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2131, 'Testers-Mini', '/Applications/GitHub Desktop.app', '3.1.3'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2132, 'Testers-Mini', '/Applications/Google Chrome.app', '113.0.5672.92'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2133, 'Testers-Mini', '/Applications/JetBrains Toolbox.app', '1.27.2.13801'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2134, 'Testers-Mini', '/Applications/Microsoft Outlook.app', '16.69.1'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2135, 'Testers-Mini', '/Applications/Microsoft Teams.app', '1.00.611156'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2136, 'Testers-Mini', '/Applications/Obsidian.app', '1.1.9'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2137, 'Testers-Mini', '/Applications/Postman.app', '10.13.0'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2138, 'Testers-Mini', '/Applications/Safari.app', '16.4'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2139, 'Testers-Mini', '/Applications/Visual Studio Code.app', '1.77.3'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2140, 'Testers-Mini', '/Applications/Visual Studio.app', '17.4.3.21'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2141, 'Testers-Mini', '/Applications/Xamarin Profiler.app', '1.8.0.19'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2142, 'Testers-Mini', '/Applications/Xcode.app', '14.2'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2143, 'Testers-Mini', '/Applications/zoom.us.app', '5.13.7 (15481)'),
#  ('ZPPLAINCORP-MAC', 'salty', 'Regular', 'macOS 13.2 (22D49)', '13.2', 'Apple M2 Pro', 'PAFA6GX4PY', None, 2711, 'ZPPLAINCORP-MAC', '/Applications/Bitwarden.app', '2023.1.1')]

# %% [markdown]
# - Upon executing another query to verify this interesting finding, it became obvious that the CMS program must have an issue with all macOS computers, as none contained within the database have a listed last full scan date. This could simply be a problem with the date reporting specific to macOS, but further investigation should be performed to ensure that the CMS is functioning properly on macOS.

# %%
# %%sql
# SELECT * FROM computers c
# INNER JOIN installed_programs i ON c.computer_name = i.computer_name
# WHERE c.operating_system LIKE "macOS%"
# Out:
#  * sqlite:///cms.sqlite
# Done.
# [('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2113, 'Testers-Mac-mini', '/Applications/Bitwarden.app', '2023.1.1'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2114, 'Testers-Mac-mini', '/Applications/Firefox.app', '114.0.1'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2115, 'Testers-Mac-mini', '/Applications/GitHub Desktop.app', '3.3.3'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2116, 'Testers-Mac-mini', '/Applications/Google Chrome.app', '117.0.5938.149'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2117, 'Testers-Mac-mini', '/Applications/JetBrains Toolbox.app', '1.27.2.13801'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2118, 'Testers-Mac-mini', '/Applications/Microsoft Outlook.app', '16.69.1'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2119, 'Testers-Mac-mini', '/Applications/Microsoft Teams.app', '1.00.624065'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2120, 'Testers-Mac-mini', '/Applications/Obsidian.app', '1.1.9'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2121, 'Testers-Mac-mini', '/Applications/Postman.app', '10.13.0'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2122, 'Testers-Mac-mini', '/Applications/Safari.app', '17.0'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2123, 'Testers-Mac-mini', '/Applications/Splashtop Streamer.app', '3.5.8.1'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2124, 'Testers-Mac-mini', '/Applications/Visual Studio Code.app', '1.82.2'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2125, 'Testers-Mac-mini', '/Applications/Visual Studio.app', '17.4.3.21'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2126, 'Testers-Mac-mini', '/Applications/Xamarin Profiler.app', '1.8.0.19'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2127, 'Testers-Mac-mini', '/Applications/Xcode.app', '14.2'),
#  ('Testers-Mac-mini', 'tester', 'Regular', 'macOS 14.0 (23A344)', '14.0', 'Apple M1', 'I4D1JABUIO3A', None, 2128, 'Testers-Mac-mini', '/Applications/zoom.us.app', '5.13.7 (15481)'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2129, 'Testers-Mini', '/Applications/Bitwarden.app', '2023.1.1'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2130, 'Testers-Mini', '/Applications/Firefox.app', '111.0.1'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2131, 'Testers-Mini', '/Applications/GitHub Desktop.app', '3.1.3'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2132, 'Testers-Mini', '/Applications/Google Chrome.app', '113.0.5672.92'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2133, 'Testers-Mini', '/Applications/JetBrains Toolbox.app', '1.27.2.13801'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2134, 'Testers-Mini', '/Applications/Microsoft Outlook.app', '16.69.1'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2135, 'Testers-Mini', '/Applications/Microsoft Teams.app', '1.00.611156'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2136, 'Testers-Mini', '/Applications/Obsidian.app', '1.1.9'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2137, 'Testers-Mini', '/Applications/Postman.app', '10.13.0'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2138, 'Testers-Mini', '/Applications/Safari.app', '16.4'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2139, 'Testers-Mini', '/Applications/Visual Studio Code.app', '1.77.3'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2140, 'Testers-Mini', '/Applications/Visual Studio.app', '17.4.3.21'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2141, 'Testers-Mini', '/Applications/Xamarin Profiler.app', '1.8.0.19'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2142, 'Testers-Mini', '/Applications/Xcode.app', '14.2'),
#  ('Testers-Mini', 'tester', 'Regular', 'macOS 13.3.1 (a) (22E772610a)', '13.3.1 (a) (22E772610a)', 'Apple M1', 'I4D1JABUIO3A', None, 2143, 'Testers-Mini', '/Applications/zoom.us.app', '5.13.7 (15481)'),
#  ('ZPPLAINCORP-MAC', 'salty', 'Regular', 'macOS 13.2 (22D49)', '13.2', 'Apple M2 Pro', 'PAFA6GX4PY', None, 2711, 'ZPPLAINCORP-MAC', '/Applications/Bitwarden.app', '2023.1.1')]

# %% [markdown]
# - As time for this assignment is limited, this will conclude the extremely minimal EDA portion. However, further opportunities for analysis include:
#     1. Pie chart visualization to show the ratios for operating system and user types
#     2. Time series analysis for login times, especially on the basis of user privilege
